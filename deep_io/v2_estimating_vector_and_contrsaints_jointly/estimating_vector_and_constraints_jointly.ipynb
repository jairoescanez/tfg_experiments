# %% [markdown]
# In this notebook we will implement a neural network that can learn the parameters of a linear optimization problem.

# %% [markdown]
# # Part 1: data obtaining and preprocessing

# %%
import numpy as np
import deep_inv_opt as io
import deep_inv_opt.plot as iop
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split

from diffcp import SolverError
import torch
import cvxpy as cp
from cvxpylayers.torch import CvxpyLayer
import contextlib
import io as io2


import matplotlib
import matplotlib.pyplot as plt
matplotlib.rcParams['figure.max_open_warning'] = 0  # Let the plots flow!
# %matplotlib inline

# %%
u_train = io.tensor(np.linspace(-1.5, 1.5, 1024).reshape((-1, 1)))

# %%
u_train, u_val = train_test_split(u_train, test_size=0.2, random_state=42)

u_train, u_test = train_test_split(u_train, test_size=0.15, random_state=42)

# %% [markdown]
# Now we generate the data from the real problem.

# %%
class ExamplePLP(io.ParametricLP):
    # Generate an LP from a given feature vector u and weight vector w.
    def generate(self, u, w):
        c = [[torch.cos(w[0] + w[1]*u)],
             [torch.sin(w[0] + w[1]*u)]]

        A_ub = [[-1.0,  0.0],
                [ 0.0, -1.0],
                [ w[0], 1 + w[1]*u/3]]

        b_ub = [[ 0.2*w[0]*u],
                [-0.2*w[1]*u],
                [ w[0] + 0.1*u]]
        
        return c, A_ub, b_ub, None, None

# %%
plp_true = ExamplePLP(weights=[1.0, 1.0])

# Generate training targets by solve the true PLP.
x_train = torch.cat([io.linprog(*plp_true(ui)).detach().t() for ui in u_train])
# torch.save(x_train, "x_train.pt")

x_val = torch.cat([io.linprog(*plp_true(ui)).detach().t() for ui in u_val])
# torch.save(x_val, "x_val.pt")

x_test = torch.cat([io.linprog(*plp_true(ui)).detach().t() for ui in u_test])
# torch.save(x_test, "x_test.pt")

# %%
# x_val = torch.load("x_val.pt")
x_val
# Out:
# tensor([[-0.0079,  0.0079],
#         [ 0.0906, -0.0906],
#         [ 0.0396, -0.0396],
#         [ 0.2818,  1.0886],
#         [-0.0624,  0.0625],
#         [-0.0443,  0.0443],
#         [ 0.0378, -0.0378],
#         [ 0.9063,  0.1305],
#         [ 0.2554,  1.0741],
#         [ 0.9164,  0.1194],
#         [ 0.0830, -0.0830],
#         [ 0.2589,  1.0759],
#         [-0.0970,  0.0971],
#         [ 0.2408,  1.0670],
#         [-0.0642,  0.0642],
#         [-0.0830,  0.0830],
#         [ 0.1358, -0.1358],
#         [ 0.0507, -0.0507],
#         [ 0.0631, -0.0630],
#         [ 0.8980,  0.1393],
#         [ 0.2437,  1.0684],
#         [ 0.7980,  0.2290],
#         [ 0.1469, -0.1469],
#         [ 0.1170, -0.1170],
#         [-0.0108,  0.0109],
#         [-0.1080,  0.1082],
#         [ 0.0877, -0.0877],
#         [ 0.1305, -0.1305],
#         [ 0.8098,  0.2197],
#         [ 0.7208,  0.2859],
#         [-0.0583,  0.0584],
#         [-0.1075,  0.1076],
#         [ 0.7122,  0.2918],
#         [ 0.1082, -0.1082],
#         [ 0.0589, -0.0589],
#         [ 0.1323, -0.1322],
#         [ 0.1751, -0.1750],
#         [-0.0695,  0.0695],
#         [ 0.0466, -0.0466],
#         [ 0.1833, -0.1832],
#         [-0.0742,  0.0742],
#         [ 0.7499,  0.2654],
#         [ 0.8484,  0.1868],
#         [-0.0466,  0.0466],
#         [ 0.0202, -0.0202],
#         [ 0.0689, -0.0689],
#         [ 0.7722,  0.2490],
#         [ 0.1569, -0.1569],
#         [-0.0595,  0.0595],
#         [ 0.1299, -0.1299],
#         [ 0.8025,  0.2255],
#         [-0.0771,  0.0771],
#         [ 0.2654,  1.0793],
#         [-0.1028,  0.1029],
#         [ 0.1129, -0.1129],
#         [ 0.2941,  1.0961],
#         [ 0.1610, -0.1610],
#         [ 0.1053, -0.1053],
#         [ 0.9185,  0.1147],
#         [ 0.2496,  1.0712],
#         [ 0.7225,  0.2848],
#         [ 0.1980, -0.1975],
#         [ 0.0126, -0.0126],
#         [ 0.8793,  0.1581],
#         [ 0.1721, -0.1721],
#         [ 0.2824,  1.0889],
#         [-0.0841,  0.0842],
#         [-0.1069,  0.1070],
#         [ 0.2683,  1.0809],
#         [ 0.2865,  1.0914],
#         [ 0.1499, -0.1498],
#         [ 0.0343, -0.0343],
#         [ 0.2982,  1.0988],
#         [-0.0490,  0.0490],
#         [-0.0249,  0.0249],
#         [ 0.9148,  0.1211],
#         [ 0.7651,  0.2543],
#         [ 0.8775,  0.1598],
#         [-0.0894,  0.0894],
#         [ 0.8726,  0.1645],
#         [ 0.1375, -0.1375],
#         [ 0.8061,  0.2226],
#         [ 0.7343,  0.2765],
#         [ 0.0947, -0.0947],
#         [-0.0173,  0.0173],
#         [ 0.1739, -0.1739],
#         [ 0.9036,  0.1334],
#         [ 0.1188, -0.1188],
#         [ 0.0097, -0.0097],
#         [ 0.0279, -0.0279],
#         [ 0.2771,  1.0858],
#         [ 0.1645, -0.1645],
#         [-0.0701,  0.0701],
#         [ 0.1070, -0.1070],
#         [-0.0331,  0.0331],
#         [ 0.2613,  1.0771],
#         [ 0.7906,  0.2349],
#         [ 0.2607,  1.0768],
#         [ 0.0173, -0.0173],
#         [ 0.1211, -0.1211],
#         [ 0.8039,  0.2243],
#         [ 0.2372,  1.0654],
#         [ 0.8133,  0.2167],
#         [ 0.7113,  0.2924],
#         [ 0.1246, -0.1246],
#         [-0.0214,  0.0214],
#         [ 0.7182,  0.2877],
#         [ 0.7776,  0.2449],
#         [ 0.0994, -0.0994],
#         [ 0.9169,  0.1188],
#         [ 0.7768,  0.2455],
#         [-0.0918,  0.0918],
#         [ 0.2414,  1.0673],
#         [ 0.2484,  1.0706],
#         [ 0.2631,  1.0780],
#         [ 0.8384,  0.1956],
#         [ 0.8069,  0.2220],
#         [ 0.2185,  1.0572],
#         [ 0.8923,  0.1452],
#         [-0.0619,  0.0619],
#         [ 0.8744,  0.1628],
#         [-0.0912,  0.0912],
#         [-0.1034,  0.1035],
#         [ 0.2361,  1.0648],
#         [ 0.7009,  0.2994],
#         [-0.0824,  0.0824],
#         [-0.0138,  0.0138],
#         [ 0.0666, -0.0666],
#         [ 0.7392,  0.2730],
#         [ 0.2202,  1.0580],
#         [ 0.1158, -0.1158],
#         [ 0.0155, -0.0155],
#         [ 0.8946,  0.1428],
#         [ 0.2073,  1.0527],
#         [ 0.0941, -0.0941],
#         [ 0.1076, -0.1076],
#         [-0.0882,  0.0883],
#         [ 0.7667,  0.2531],
#         [ 0.1510, -0.1510],
#         [ 0.0167, -0.0167],
#         [ 0.8888,  0.1487],
#         [ 0.1921, -0.1920],
#         [ 0.7838,  0.2402],
#         [-0.0982,  0.0982],
#         [ 0.8010,  0.2267],
#         [ 0.1774, -0.1774],
#         [ 0.2015,  1.0498],
#         [ 0.8226,  0.2091],
#         [ 0.7958,  0.2308],
#         [ 0.7035,  0.2977],
#         [-0.0185,  0.0185],
#         [ 0.2677,  1.0806],
#         [ 0.2296,  1.0620],
#         [ 0.8556,  0.1804],
#         [ 0.2853,  1.0907],
#         [ 0.2578,  1.0753],
#         [ 0.8491,  0.1862],
#         [ 0.2742,  1.0841],
#         [ 0.0425, -0.0425],
#         [ 0.1839, -0.1838],
#         [-0.0988,  0.0988],
#         [ 0.7564,  0.2607],
#         [-0.0237,  0.0238],
#         [ 0.1780, -0.1780],
#         [ 0.0068, -0.0067],
#         [ 0.0150, -0.0150],
#         [ 0.0760, -0.0759],
#         [-0.0871,  0.0871],
#         [-0.0671,  0.0672],
#         [ 0.8112,  0.2185],
#         [ 0.8670,  0.1698],
#         [ 0.7515,  0.2642],
#         [ 0.1047, -0.1047],
#         [ 0.1768, -0.1768],
#         [ 0.8738,  0.1633],
#         [ 0.2648,  1.0790],
#         [ 0.0355, -0.0355],
#         [ 0.0073, -0.0073],
#         [ 0.7191,  0.2871],
#         [-0.0484,  0.0484],
#         [-0.0038,  0.0038],
#         [ 0.1475, -0.1475],
#         [ 0.9030,  0.1340],
#         [ 0.0607, -0.0607],
#         [ 0.1135, -0.1135],
#         [ 0.1106, -0.1105],
#         [ 0.1287, -0.1287],
#         [-0.0067,  0.0067],
#         [-0.0536,  0.0537],
#         [ 0.0290, -0.0290],
#         [ 0.7458,  0.2683],
#         [ 0.2355,  1.0646],
#         [ 0.0103, -0.0103],
#         [-0.0015,  0.0015],
#         [ 0.0894, -0.0894],
#         [ 0.7995,  0.2279],
#         [ 0.7860,  0.2384],
#         [ 0.1387, -0.1387],
#         [ 0.8720,  0.1651],
#         [ 0.0484, -0.0484],
#         [-0.0179,  0.0179],
#         [ 0.7973,  0.2296],
#         [-0.0097,  0.0097],
#         [ 0.1276, -0.1276],
#         [ 0.9002,  0.1370]], dtype=torch.float64)

# %%
# x_train = torch.load("x_train.pt")
x_train
# Out:
# tensor([[-0.0325,  0.0326],
#         [ 0.8569,  0.1792],
#         [ 0.7139,  0.2906],
#         ...,
#         [-0.1000,  0.1000],
#         [ 0.1997, -0.1958],
#         [-0.0542,  0.0543]], dtype=torch.float64)

# %%
# x_test = torch.load("x_test.pt")
x_test
# Out:
# tensor([[ 7.7452e-01,  2.4722e-01],
#         [ 7.7839e-01,  2.4428e-01],
#         [ 2.2376e-01,  1.0594e+00],
#         [ 7.3008e-01,  2.7948e-01],
#         [ 7.0679e-02, -7.0669e-02],
#         [ 2.1613e-01,  1.0563e+00],
#         [ 1.6863e-01, -1.6859e-01],
#         [-2.9607e-02,  2.9624e-02],
#         [ 1.9854e-01, -1.9775e-01],
#         [ 1.2816e-01, -1.2814e-01],
#         [-9.0834e-03,  9.0953e-03],
#         [ 2.5602e-01,  1.0744e+00],
#         [ 5.4843e-02, -5.4834e-02],
#         [ 8.4044e-01,  1.9385e-01],
#         [ 9.0033e-02, -9.0023e-02],
#         [-8.1787e-02,  8.1823e-02],
#         [ 2.7302e-01,  1.0835e+00],
#         [ 5.6603e-02, -5.6593e-02],
#         [ 1.9091e-01, -1.9080e-01],
#         [ 9.0191e-01,  1.3519e-01],
#         [ 5.1324e-02, -5.1315e-02],
#         [ 2.0792e-01,  1.0529e+00],
#         [-4.3094e-02,  4.3114e-02],
#         [ 9.7071e-02, -9.7060e-02],
#         [ 1.9150e-01, -1.9138e-01],
#         [-7.3582e-02,  7.3612e-02],
#         [-3.8403e-02,  3.8422e-02],
#         [ 5.1911e-02, -5.1901e-02],
#         [ 1.2288e-01, -1.2286e-01],
#         [ 9.0741e-01,  1.2933e-01],
#         [-2.8687e-04,  2.9734e-04],
#         [ 8.8703e-01,  1.5044e-01],
#         [-1.1170e-01,  1.1232e-01],
#         [-1.2602e-02,  1.2614e-02],
#         [ 7.6749e-01,  2.5250e-01],
#         [ 8.7627e-01,  1.6100e-01],
#         [ 1.0352e-01, -1.0351e-01],
#         [ 1.9561e-01, -1.9537e-01],
#         [ 2.0675e-01,  1.0524e+00],
#         [ 2.8886e-01,  1.0928e+00],
#         [ 2.9624e-02, -2.9614e-02],
#         [-8.8829e-02,  8.8860e-02],
#         [ 2.7596e-01,  1.0851e+00],
#         [ 2.6247e-01,  1.0777e+00],
#         [ 7.1046e-01,  2.9297e-01],
#         [ 1.4399e-01, -1.4398e-01],
#         [-4.0749e-02,  4.0768e-02],
#         [-4.1921e-02,  4.1941e-02],
#         [ 1.3637e-01, -1.3635e-01],
#         [-5.4822e-02,  5.4844e-02],
#         [ 8.7990e-01,  1.5748e-01],
#         [ 8.0830e-01,  2.2082e-01],
#         [ 2.0591e-03, -2.0487e-03],
#         [ 8.7506e-01,  1.6217e-01],
#         [ 1.6393e-01, -1.6390e-01],
#         [ 7.9239e-03, -7.9137e-03],
#         [ 2.3021e-01,  1.0622e+00],
#         [ 7.6115e-01,  2.5719e-01],
#         [ 2.0827e-02, -2.0817e-02],
#         [ 3.1383e-02, -3.1374e-02],
#         [-7.1824e-02,  7.1853e-02],
#         [ 1.6335e-01, -1.6332e-01],
#         [ 7.6433e-01,  2.5484e-01],
#         [ 7.6827e-01,  2.5191e-01],
#         [-7.2996e-02,  7.3026e-02],
#         [ 2.5132e-01,  1.0721e+00],
#         [-6.4789e-02,  6.4815e-02],
#         [ 8.6952e-01,  1.6745e-01],
#         [ 9.1380e-01,  1.2229e-01],
#         [ 7.2332e-01,  2.8417e-01],
#         [ 9.0904e-01,  1.2757e-01],
#         [ 9.0412e-01,  1.3285e-01],
#         [ 2.8417e-01,  1.0900e+00],
#         [ 4.1940e-02, -4.1931e-02],
#         [ 2.3783e-01,  1.0656e+00],
#         [ 7.3092e-01,  2.7889e-01],
#         [ 1.0587e-01, -1.0586e-01],
#         [-1.0112e-01,  1.0118e-01],
#         [ 4.7219e-02, -4.7209e-02],
#         [ 8.3366e-01,  1.9971e-01],
#         [ 7.6591e-01,  2.5367e-01],
#         [-1.0401e-01,  1.0411e-01],
#         [ 7.2417e-01,  2.8358e-01],
#         [ 1.4165e-01, -1.4163e-01],
#         [ 1.0856e-02, -1.0846e-02],
#         [ 1.3519e-01, -1.3518e-01],
#         [ 8.9053e-01,  1.4693e-01],
#         [ 8.2953e-01,  2.0323e-01],
#         [ 1.0059e-01, -1.0058e-01],
#         [-8.1201e-02,  8.1237e-02],
#         [ 5.5430e-02, -5.5420e-02],
#         [-4.5440e-02,  4.5460e-02],
#         [ 8.3091e-01,  2.0206e-01],
#         [ 2.9003e-01,  1.0935e+00],
#         [ 7.1564e-01,  2.8945e-01],
#         [ 1.3789e-02, -1.3779e-02],
#         [ 2.1672e-01,  1.0565e+00],
#         [ 2.4932e-02, -2.4922e-02],
#         [-2.7850e-02,  2.7863e-02],
#         [-1.0914e-01,  1.0939e-01],
#         [-2.9023e-02,  2.9036e-02],
#         [ 9.1781e-01,  1.1760e-01],
#         [ 1.4810e-01, -1.4808e-01],
#         [-8.7657e-02,  8.7687e-02],
#         [ 3.6075e-02, -3.6066e-02],
#         [ 9.0850e-01,  1.2816e-01],
#         [ 1.4375e-02, -1.4365e-02],
#         [ 1.5983e-01, -1.5980e-01],
#         [ 2.3173e-02, -2.3163e-02],
#         [ 8.0903e-01,  2.2024e-01],
#         [-7.9443e-02,  7.9477e-02],
#         [ 7.6354e-01,  2.5543e-01],
#         [ 1.5220e-01, -1.5218e-01],
#         [ 9.8831e-02, -9.8820e-02],
#         [ 8.9855e-01,  1.3871e-01],
#         [ 2.9062e-01,  1.0939e+00],
#         [-7.0651e-02,  7.0680e-02],
#         [-1.4362e-02,  1.4374e-02],
#         [-2.1986e-02,  2.1998e-02],
#         [ 2.2845e-01,  1.0614e+00],
#         [-6.1517e-03,  6.1624e-03],
#         [ 6.1644e-03, -6.1542e-03],
#         [ 7.8452e-01,  2.3959e-01]], dtype=torch.float64)

# %% [markdown]
# # Part 2: model definition and training

# %%
# Check if we are using a GPU or CPU
device = torch.accelerator.current_accelerator().type if torch.accelerator.is_available() else "cpu"
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
learning_rate = 1e-3
batch_size = 16

# %%
# Dataset and DataLoader definition
class UDataset(Dataset):
    def __init__(self, data, targets):
        self.data = data.clone().to(dtype=torch.float32) 
        self.targets = targets.clone().to(dtype=torch.float32)

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        return self.data[idx], self.targets[idx]

# Dataset (u, x)
dataset = UDataset(u_train, x_train)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

# %%
val_dataset = UDataset(u_val, x_val)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=True)

test_dataset = UDataset(u_test, x_test)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True)

# %%
def gradient_descent_solver(c, A, b, lr=0.01, max_iter=1000, tol=1e-6, M=1000.0):
    """
    Solve a linear optimization problem with constraints using gradient descent.

    Parameters:
    - c: Cost vector (n,)
    - A: Constraint matrix (m, n)
    - b: Constraint vector (m,)
    - lr: Learning rate
    - max_iter: Maximum number of iterations
    - tol: Convergence tolerance

    Returns:
    - x: Optimal solution found
    """
    n = c.shape[0]
    x = torch.zeros(n, dtype=c.dtype, requires_grad=True)
    optimizer = torch.optim.SGD([x], lr=lr)

    for _ in range(max_iter):
        optimizer.zero_grad()
        objective = torch.dot(c, x) + M * torch.sum(torch.relu(A @ x - b)) # relu(x) = max(0, x)
        objective.backward(retain_graph=True)
        optimizer.step()

        if torch.norm(x.grad) < tol:
            break
    return x

def newton_solver(c, A, b, max_iter=100, tol=1e-6, M=1000.0):
    """
    Solve a linear optimization problem with constraints using the Newton method.

    Parameters:
    - c: Cost vector (n,)
    - A: Constraint matrix (m, n)
    - b: Constraint vector (m,)
    - max_iter: Maximum number of iterations
    - tol: Convergence tolerance

    Returns:
    - x: Optimal solution found
    """
    n = c.shape[0]
    x = torch.zeros(n, dtype=c.dtype, requires_grad=True)
    
    for _ in range(max_iter):
        loss = torch.dot(c, x) + M * torch.sum(torch.relu(A @ x - b))

        # Gradient and Hessian
        grad = torch.autograd.grad(loss, x, create_graph=True)[0]
        hess = torch.autograd.functional.hessian(lambda y: torch.dot(c, y) + M * torch.sum(torch.relu(A @ y - b)), x)

        # Newton step: Δx = -H⁻¹ * grad
        try:
            delta_x = torch.linalg.solve(hess, -grad)
        except RuntimeError:
            break  # Break if the Hessian is singular

        # Actualize x
        x = x + delta_x

        # Break if converged
        if torch.norm(delta_x) < tol:
            break

    return x

# %%
def solver(c_, A_, b_):
    try:
        M = 1000.0
        m, n = A_.shape

        A = cp.Parameter((m, n))
        b = cp.Parameter(m)
        c = cp.Parameter(n)
        x = cp.Variable(n)

        obj = cp.Minimize(c.T @ x + M * cp.sum(cp.pos(A @ x - b))) # cp.pos = max(0, x)

        cons = [0 * x >= 0]

        prob = cp.Problem(obj, cons)
        layer = CvxpyLayer(prob, parameters=[c, A, b], variables=[x])

        with io2.StringIO() as buf, contextlib.redirect_stdout(buf):
            solution, = layer(c_, A_, b_)
        return solution

    except SolverError:
        return newton_solver(c_, A_, b_)

# %%
# Define the model
class ParametricLPNet(nn.Module):
    def __init__(self):
        super(ParametricLPNet, self).__init__()
        self.fc = nn.Sequential(
            nn.Linear(1, 12),
            nn.ReLU(),
            nn.Linear(12, 40),
            nn.ReLU(),
            nn.Linear(40, 150),
            nn.ReLU(),
            nn.Linear(150, 300),
            nn.ReLU(),
            nn.Linear(300, 150),
            nn.ReLU(),
            nn.Linear(150, 90),
            nn.ReLU(),
            nn.Linear(90, 40),
            nn.Sigmoid(),
            nn.Linear(40, 14)
        )
    def forward(self, u):
        output = self.fc(u)        
        c = output[:, 0:2]
        A = output[:, 2:10].reshape(-1, 4, 2)
        b = output[:, 10:14]
        return torch.stack(list(map(solver, c, A, b)))

# %%
loss_fn = nn.MSELoss()

# %%
model = ParametricLPNet()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
# optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate) # elegir una de las dos

# %%
model
# Out:
# ParametricLPNet(
#   (fc): Sequential(
#     (0): Linear(in_features=1, out_features=12, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=12, out_features=40, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=40, out_features=150, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=150, out_features=300, bias=True)
#     (7): ReLU()
#     (8): Linear(in_features=300, out_features=150, bias=True)
#     (9): ReLU()
#     (10): Linear(in_features=150, out_features=90, bias=True)
#     (11): ReLU()
#     (12): Linear(in_features=90, out_features=40, bias=True)
#     (13): Sigmoid()
#     (14): Linear(in_features=40, out_features=14, bias=True)
#   )
# )

# %%
# Initialize the weights of the model
def initialize_weights(m):
    if isinstance(m, nn.Linear):
        nn.init.kaiming_normal_(m.weight, nonlinearity='leaky_relu') # inicializamos los pesos de la red con Kaiming
        nn.init.zeros_(m.bias) # inicializamos los bias a 0

# initialize_weights(model)


# We load the trained model weights
model.load_state_dict(torch.load("model_weights.pth"))
# Out:
# <All keys matched successfully>

# %%
def near(rs, x_batch, tol=1e-3):
    '''
    rs: Tensor containing the solutions of the LPs  
    x_batch: Tensor containing the desired solutions of the LPs  
    tol: Tolerance to consider two vectors as equal  

    This function calculates the number of LP solutions that are within a distance  
    less than tol from the desired solutions.
    '''
    d = torch.sum((rs - x_batch) ** 2, dim=1)
    return torch.sum(d < tol).item()

# %%
tol = 0.0001

def train_loop(dataloader, model, loss_fn, optimizer):
    model.train()
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    loss_media = 0.0
    accuracy = 0.0
    batch_size = dataloader.batch_size
    for batch, (u_batch, x_batch) in enumerate(dataloader):

        rs = model(u_batch)
        loss = loss_fn(rs, x_batch)

        # Backpropagation and optimization
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

        if batch % 8 == 0:
            loss = loss.item()
            current = batch * batch_size + batch_size
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")
            
        loss_media += loss
        accuracy += near(rs, x_batch, tol)

    return loss_media / num_batches, accuracy / size

# %%
def val_loop(dataloader, model, loss_fn):
    model.eval()
    size=len(dataloader.dataset)
    num_batches = len(dataloader)
    val_loss, correct = 0, 0

    for u_batch, x_batch in dataloader:
        rs = model(u_batch)
        val_loss += loss_fn(rs, x_batch).item()
        correct += near(rs, x_batch, tol) # correct is the number of LP solutions that are within a distance less than tol from the desired solutions.
    val_loss /= num_batches
    correct /= size
    print(f"Validation Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {val_loss:>8f} \n\n")
    return val_loss, correct

# %%
val_acc = []
val_loss = []
train_acc = []
train_loss = []

# train_acc = torch.load("train_acc.pth")
# val_acc = torch.load("val_acc.pth")
# train_loss = torch.load("train_loss.pth")
# val_loss = torch.load("val_loss.pth")

# %%
# Entrenamiento
epochs = 2000

for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    loss, accuracy = train_loop(dataloader, model, loss_fn, optimizer)
    train_acc.append(accuracy)
    train_loss.append(loss.clone().detach())
    print(f"\nTraining Error: \n Accuracy: {(100*accuracy):>0.1f}%, Avg loss: {loss:>8f} \n")
    
    loss_val, accuracy_val = val_loop(val_dataloader, model, loss_fn)
    val_acc.append(accuracy_val)
    val_loss.append(loss_val)

print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 0.000099  [   16/  696]
# loss: 0.000337  [  144/  696]
# loss: 0.000222  [  272/  696]
# loss: 0.000232  [  400/  696]
# loss: 0.002702  [  528/  696]
# loss: 0.000216  [  656/  696]
#
# Training Error:
#  Accuracy: 16.2%, Avg loss: 0.004591
#
# Validation Error:
#  Accuracy: 36.1%, Avg loss: 0.004784
#
#
# Epoch 2
# -------------------------------
# loss: 0.000382  [   16/  696]
# loss: 0.005751  [  144/  696]
# loss: 0.006487  [  272/  696]
# loss: 0.023886  [  400/  696]
# loss: 0.001310  [  528/  696]
# loss: 0.002599  [  656/  696]
#
# Training Error:
#  Accuracy: 11.1%, Avg loss: 0.007263
#
# Validation Error:
#  Accuracy: 1.0%, Avg loss: 0.008987
#
#
# Epoch 3
# -------------------------------
# loss: 0.001006  [   16/  696]
# loss: 0.025127  [  144/  696]
# loss: 0.000324  [  272/  696]
# loss: 0.000647  [  400/  696]
# loss: 0.000362  [  528/  696]
# loss: 0.003927  [  656/  696]
#
# Training Error:
#  Accuracy: 8.8%, Avg loss: 0.005183
#
# Validation Error:
#  Accuracy: 1.0%, Avg loss: 0.003067
#
#
# Epoch 4
# -------------------------------
# loss: 0.000251  [   16/  696]
# loss: 0.001887  [  144/  696]
# loss: 0.027478  [  272/  696]
# loss: 0.002458  [  400/  696]
# loss: 0.000373  [  528/  696]
# loss: 0.001090  [  656/  696]
#
# Training Error:
#  Accuracy: 9.3%, Avg loss: 0.009979
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.004267
#
#
# Epoch 5
# -------------------------------
# loss: 0.028907  [   16/  696]
# loss: 0.006270  [  144/  696]
# loss: 0.002451  [  272/  696]
# loss: 0.002377  [  400/  696]
# loss: 0.002192  [  528/  696]
# loss: 0.035049  [  656/  696]
#
# Training Error:
#  Accuracy: 3.6%, Avg loss: 0.009726
#
# Validation Error:
#  Accuracy: 0.5%, Avg loss: 0.008112
#
#
# Epoch 6
# -------------------------------
# loss: 0.056523  [   16/  696]
# loss: 0.001872  [  144/  696]
# loss: 0.002532  [  272/  696]
# loss: 0.000815  [  400/  696]
# loss: 0.001732  [  528/  696]
# loss: 0.004045  [  656/  696]
#
# Training Error:
#  Accuracy: 4.9%, Avg loss: 0.008078
#
# Validation Error:
#  Accuracy: 0.0%, Avg loss: 0.009267
#
#
# Epoch 7
# -------------------------------
# loss: 0.026462  [   16/  696]
# loss: 0.000731  [  144/  696]
# loss: 0.001987  [  272/  696]
# loss: 0.002900  [  400/  696]
# loss: 0.000517  [  528/  696]
# loss: 0.023025  [  656/  696]
#
# Training Error:
#  Accuracy: 5.3%, Avg loss: 0.007536
#
# Validation Error:
#  Accuracy: 0.0%, Avg loss: 0.006584
#
#
# Epoch 8
# -------------------------------
# loss: 0.001084  [   16/  696]
# loss: 0.001827  [  144/  696]
# loss: 0.016619  [  272/  696]
# loss: 0.000799  [  400/  696]
# loss: 0.000666  [  528/  696]
# loss: 0.008096  [  656/  696]
#
# Training Error:
#  Accuracy: 10.1%, Avg loss: 0.004384
#
# Validation Error:
#  Accuracy: 4.4%, Avg loss: 0.003964
#
#
# Epoch 9
# -------------------------------
# loss: 0.000673  [   16/  696]
# loss: 0.000884  [  144/  696]
# loss: 0.000565  [  272/  696]
# loss: 0.001061  [  400/  696]
# loss: 0.089427  [  528/  696]
# loss: 0.005561  [  656/  696]
#
# Training Error:
#  Accuracy: 10.3%, Avg loss: 0.009957
#
# Validation Error:
#  Accuracy: 0.5%, Avg loss: 0.006251
#
#
# Epoch 10
# -------------------------------
# loss: 0.002149  [   16/  696]
# loss: 0.001087  [  144/  696]
# loss: 0.005371  [  272/  696]
# loss: 0.000831  [  400/  696]
# loss: 0.001496  [  528/  696]
# loss: 0.006728  [  656/  696]
#
# Training Error:
#  Accuracy: 6.6%, Avg loss: 0.005507
#
# Validation Error:
#  Accuracy: 2.4%, Avg loss: 0.009349
#
#
# Epoch 11
# -------------------------------
# loss: 0.001550  [   16/  696]
# loss: 0.003036  [  144/  696]
# loss: 0.000851  [  272/  696]
# loss: 0.010414  [  400/  696]
# loss: 0.001105  [  528/  696]
# loss: 0.000964  [  656/  696]
#
# Training Error:
#  Accuracy: 4.7%, Avg loss: 0.011113
#
# Validation Error:
#  Accuracy: 2.4%, Avg loss: 0.006193
#
#
# Epoch 12
# -------------------------------
# loss: 0.002434  [   16/  696]
# loss: 0.000512  [  144/  696]
# loss: 0.000824  [  272/  696]
# loss: 0.001095  [  400/  696]
# loss: 0.001208  [  528/  696]
# loss: 0.001301  [  656/  696]
#
# Training Error:
#  Accuracy: 7.8%, Avg loss: 0.006899
#
# Validation Error:
#  Accuracy: 31.2%, Avg loss: 0.004110
#
#
# Epoch 13
# -------------------------------
# loss: 0.011495  [   16/  696]
# loss: 0.000961  [  144/  696]
# loss: 0.000796  [  272/  696]
# loss: 0.000308  [  400/  696]
# loss: 0.003286  [  528/  696]
# loss: 0.001008  [  656/  696]
#
# Training Error:
#  Accuracy: 8.2%, Avg loss: 0.006898
#
# Validation Error:
#  Accuracy: 0.0%, Avg loss: 0.004089
#
#
# Epoch 14
# -------------------------------
# loss: 0.001274  [   16/  696]
# loss: 0.010916  [  144/  696]
# loss: 0.012391  [  272/  696]
# loss: 0.019399  [  400/  696]
# loss: 0.000437  [  528/  696]
# loss: 0.000781  [  656/  696]
#
# Training Error:
#  Accuracy: 12.1%, Avg loss: 0.006187
#
# Validation Error:
#  Accuracy: 32.2%, Avg loss: 0.001546
#
#
# Epoch 15
# -------------------------------
# loss: 0.000291  [   16/  696]
# loss: 0.005769  [  144/  696]
# loss: 0.000933  [  272/  696]
# loss: 0.001022  [  400/  696]
# loss: 0.000289  [  528/  696]
# loss: 0.000413  [  656/  696]
#
# Training Error:
#  Accuracy: 24.4%, Avg loss: 0.004520
#
# Validation Error:
#  Accuracy: 22.4%, Avg loss: 0.003667
#
#
# Epoch 16
# -------------------------------
# loss: 0.000563  [   16/  696]
# loss: 0.003060  [  144/  696]
# loss: 0.032523  [  272/  696]
# loss: 0.003579  [  400/  696]
# loss: 0.000277  [  528/  696]
# loss: 0.016372  [  656/  696]
#
# Training Error:
#  Accuracy: 11.1%, Avg loss: 0.005612
#
# Validation Error:
#  Accuracy: 40.0%, Avg loss: 0.001539
#
#
# Epoch 17
# -------------------------------
# loss: 0.002624  [   16/  696]
# loss: 0.000219  [  144/  696]
# loss: 0.006905  [  272/  696]
# loss: 0.001237  [  400/  696]
# loss: 0.000438  [  528/  696]
# loss: 0.021131  [  656/  696]
#
# Training Error:
#  Accuracy: 38.6%, Avg loss: 0.003761
#
# Validation Error:
#  Accuracy: 1.5%, Avg loss: 0.003966
#
#
# Epoch 18
# -------------------------------
# loss: 0.021128  [   16/  696]
# loss: 0.001579  [  144/  696]
# loss: 0.000820  [  272/  696]
# loss: 0.010252  [  400/  696]
# loss: 0.000264  [  528/  696]
# loss: 0.004850  [  656/  696]
#
# Training Error:
#  Accuracy: 7.5%, Avg loss: 0.005300
#
# Validation Error:
#  Accuracy: 27.8%, Avg loss: 0.006083
#
#
# Epoch 19
# -------------------------------
# loss: 0.000592  [   16/  696]
# loss: 0.001613  [  144/  696]
# loss: 0.000461  [  272/  696]
# loss: 0.000344  [  400/  696]
# loss: 0.000295  [  528/  696]
# loss: 0.026993  [  656/  696]
#
# Training Error:
#  Accuracy: 13.1%, Avg loss: 0.007137
#
# Validation Error:
#  Accuracy: 4.4%, Avg loss: 0.005577
#
#
# Epoch 20
# -------------------------------
# loss: 0.000747  [   16/  696]
# loss: 0.006943  [  144/  696]
# loss: 0.000359  [  272/  696]
# loss: 0.000650  [  400/  696]
# loss: 0.000354  [  528/  696]
# loss: 0.000239  [  656/  696]
#
# Training Error:
#  Accuracy: 11.2%, Avg loss: 0.003770
#
# Validation Error:
#  Accuracy: 2.9%, Avg loss: 0.003533
#
#
# Epoch 21
# -------------------------------
# loss: 0.000342  [   16/  696]
# loss: 0.000372  [  144/  696]
# loss: 0.002311  [  272/  696]
# loss: 0.001142  [  400/  696]
# loss: 0.009177  [  528/  696]
# loss: 0.041232  [  656/  696]
#
# Training Error:
#  Accuracy: 19.0%, Avg loss: 0.006705
#
# Validation Error:
#  Accuracy: 13.7%, Avg loss: 0.004292
#
#
# Epoch 22
# -------------------------------
# loss: 0.001203  [   16/  696]
# loss: 0.000589  [  144/  696]
# loss: 0.001049  [  272/  696]
# loss: 0.000143  [  400/  696]
# loss: 0.004585  [  528/  696]
# loss: 0.019185  [  656/  696]
#
# Training Error:
#  Accuracy: 22.7%, Avg loss: 0.003988
#
# Validation Error:
#  Accuracy: 31.7%, Avg loss: 0.002227
#
#
# Epoch 23
# -------------------------------
# loss: 0.000926  [   16/  696]
# loss: 0.004185  [  144/  696]
# loss: 0.000262  [  272/  696]
# loss: 0.012635  [  400/  696]
# loss: 0.000143  [  528/  696]
# loss: 0.000360  [  656/  696]
#
# Training Error:
#  Accuracy: 30.0%, Avg loss: 0.002571
#
# Validation Error:
#  Accuracy: 64.4%, Avg loss: 0.000861
#
#
# Epoch 24
# -------------------------------
# loss: 0.000616  [   16/  696]
# loss: 0.000112  [  144/  696]
# loss: 0.000517  [  272/  696]
# loss: 0.014775  [  400/  696]
# loss: 0.000212  [  528/  696]
# loss: 0.028952  [  656/  696]
#
# Training Error:
#  Accuracy: 23.4%, Avg loss: 0.004383
#
# Validation Error:
#  Accuracy: 13.2%, Avg loss: 0.006792
#
#
# Epoch 25
# -------------------------------
# loss: 0.000405  [   16/  696]
# loss: 0.000185  [  144/  696]
# loss: 0.000193  [  272/  696]
# loss: 0.000314  [  400/  696]
# loss: 0.000105  [  528/  696]
# loss: 0.000116  [  656/  696]
#
# Training Error:
#  Accuracy: 20.3%, Avg loss: 0.003432
#
# Validation Error:
#  Accuracy: 40.0%, Avg loss: 0.002098
#
#
# Epoch 26
# -------------------------------
# loss: 0.000094  [   16/  696]
# loss: 0.015757  [  144/  696]
# loss: 0.027465  [  272/  696]
# loss: 0.000342  [  400/  696]
# loss: 0.000168  [  528/  696]
# loss: 0.000681  [  656/  696]
#
# Training Error:
#  Accuracy: 21.6%, Avg loss: 0.003835
#
# Validation Error:
#  Accuracy: 12.7%, Avg loss: 1.876205
#
#
# Epoch 27
# -------------------------------
# loss: 0.000181  [   16/  696]
# loss: 0.304440  [  144/  696]
# loss: 0.058593  [  272/  696]
# loss: 0.093888  [  400/  696]
# loss: 0.079271  [  528/  696]
# loss: 0.093861  [  656/  696]
#
# Training Error:
#  Accuracy: 3.6%, Avg loss: 0.311444
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.111609
#
#
# Epoch 28
# -------------------------------
# loss: 0.094144  [   16/  696]
# loss: 0.077973  [  144/  696]
# loss: 0.094442  [  272/  696]
# loss: 0.081092  [  400/  696]
# loss: 0.121976  [  528/  696]
# loss: 0.104837  [  656/  696]
#
# Training Error:
#  Accuracy: 3.4%, Avg loss: 0.116542
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.100152
#
#
# Epoch 29
# -------------------------------
# loss: 0.165151  [   16/  696]
# loss: 0.061552  [  144/  696]
# loss: 0.122625  [  272/  696]
# loss: 0.042547  [  400/  696]
# loss: 0.159210  [  528/  696]
# loss: 0.240131  [  656/  696]
#
# Training Error:
#  Accuracy: 4.2%, Avg loss: 0.111274
#
# Validation Error:
#  Accuracy: 5.4%, Avg loss: 0.097566
#
#
# Epoch 30
# -------------------------------
# loss: 0.193103  [   16/  696]
# loss: 0.040241  [  144/  696]
# loss: 0.083460  [  272/  696]
# loss: 0.201148  [  400/  696]
# loss: 0.045801  [  528/  696]
# loss: 0.116546  [  656/  696]
#
# Training Error:
#  Accuracy: 5.2%, Avg loss: 0.111873
#
# Validation Error:
#  Accuracy: 5.9%, Avg loss: 0.099243
#
#
# Epoch 31
# -------------------------------
# loss: 0.194334  [   16/  696]
# loss: 0.196876  [  144/  696]
# loss: 0.039543  [  272/  696]
# loss: 0.192999  [  400/  696]
# loss: 0.044060  [  528/  696]
# loss: 0.088597  [  656/  696]
#
# Training Error:
#  Accuracy: 5.7%, Avg loss: 0.112740
#
# Validation Error:
#  Accuracy: 7.3%, Avg loss: 0.097184
#
#
# Epoch 32
# -------------------------------
# loss: 0.117130  [   16/  696]
# loss: 0.118082  [  144/  696]
# loss: 0.087405  [  272/  696]
# loss: 0.044911  [  400/  696]
# loss: 0.081962  [  528/  696]
# loss: 0.124215  [  656/  696]
#
# Training Error:
#  Accuracy: 7.5%, Avg loss: 0.114442
#
# Validation Error:
#  Accuracy: 2.9%, Avg loss: 0.101003
#
#
# Epoch 33
# -------------------------------
# loss: 0.043716  [   16/  696]
# loss: 0.083960  [  144/  696]
# loss: 0.118658  [  272/  696]
# loss: 0.045561  [  400/  696]
# loss: 0.046628  [  528/  696]
# loss: 0.198027  [  656/  696]
#
# Training Error:
#  Accuracy: 6.5%, Avg loss: 0.112499
#
# Validation Error:
#  Accuracy: 10.7%, Avg loss: 0.098726
#
#
# Epoch 34
# -------------------------------
# loss: 0.199043  [   16/  696]
# loss: 0.086291  [  144/  696]
# loss: 0.074828  [  272/  696]
# loss: 0.271450  [  400/  696]
# loss: 0.122341  [  528/  696]
# loss: 0.117517  [  656/  696]
#
# Training Error:
#  Accuracy: 11.2%, Avg loss: 0.114282
#
# Validation Error:
#  Accuracy: 15.1%, Avg loss: 0.097200
#
#
# Epoch 35
# -------------------------------
# loss: 0.124276  [   16/  696]
# loss: 0.116307  [  144/  696]
# loss: 0.041700  [  272/  696]
# loss: 0.080106  [  400/  696]
# loss: 0.188690  [  528/  696]
# loss: 0.157670  [  656/  696]
#
# Training Error:
#  Accuracy: 10.8%, Avg loss: 0.115243
#
# Validation Error:
#  Accuracy: 13.2%, Avg loss: 0.098940
#
#
# Epoch 36
# -------------------------------
# loss: 0.122024  [   16/  696]
# loss: 0.121971  [  144/  696]
# loss: 0.085360  [  272/  696]
# loss: 0.047521  [  400/  696]
# loss: 0.015404  [  528/  696]
# loss: 0.118637  [  656/  696]
#
# Training Error:
#  Accuracy: 14.5%, Avg loss: 0.115236
#
# Validation Error:
#  Accuracy: 4.9%, Avg loss: 0.099027
#
#
# Epoch 37
# -------------------------------
# loss: 0.114521  [   16/  696]
# loss: 0.086001  [  144/  696]
# loss: 0.155034  [  272/  696]
# loss: 0.044258  [  400/  696]
# loss: 0.190573  [  528/  696]
# loss: 0.088364  [  656/  696]
#
# Training Error:
#  Accuracy: 11.9%, Avg loss: 0.112314
#
# Validation Error:
#  Accuracy: 7.8%, Avg loss: 0.099281
#
#
# Epoch 38
# -------------------------------
# loss: 0.155386  [   16/  696]
# loss: 0.086255  [  144/  696]
# loss: 0.043731  [  272/  696]
# loss: 0.119356  [  400/  696]
# loss: 0.117922  [  528/  696]
# loss: 0.040299  [  656/  696]
#
# Training Error:
#  Accuracy: 12.9%, Avg loss: 0.115530
#
# Validation Error:
#  Accuracy: 8.3%, Avg loss: 0.099953
#
#
# Epoch 39
# -------------------------------
# loss: 0.158889  [   16/  696]
# loss: 0.200487  [  144/  696]
# loss: 0.045163  [  272/  696]
# loss: 0.040769  [  400/  696]
# loss: 0.162149  [  528/  696]
# loss: 0.079134  [  656/  696]
#
# Training Error:
#  Accuracy: 14.5%, Avg loss: 0.113308
#
# Validation Error:
#  Accuracy: 13.7%, Avg loss: 0.097177
#
#
# Epoch 40
# -------------------------------
# loss: 0.241935  [   16/  696]
# loss: 0.116462  [  144/  696]
# loss: 0.117394  [  272/  696]
# loss: 0.096709  [  400/  696]
# loss: 0.117281  [  528/  696]
# loss: 0.120009  [  656/  696]
#
# Training Error:
#  Accuracy: 6.8%, Avg loss: 0.114735
#
# Validation Error:
#  Accuracy: 3.9%, Avg loss: 0.097937
#
#
# Epoch 41
# -------------------------------
# loss: 0.116391  [   16/  696]
# loss: 0.080348  [  144/  696]
# loss: 0.083552  [  272/  696]
# loss: 0.086151  [  400/  696]
# loss: 0.125392  [  528/  696]
# loss: 0.078288  [  656/  696]
#
# Training Error:
#  Accuracy: 3.0%, Avg loss: 0.113427
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.099512
#
#
# Epoch 42
# -------------------------------
# loss: 0.154568  [   16/  696]
# loss: 0.115687  [  144/  696]
# loss: 0.084512  [  272/  696]
# loss: 0.190617  [  400/  696]
# loss: 0.043731  [  528/  696]
# loss: 0.172210  [  656/  696]
#
# Training Error:
#  Accuracy: 5.9%, Avg loss: 0.118182
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.104913
#
#
# Epoch 43
# -------------------------------
# loss: 0.080093  [   16/  696]
# loss: 0.046086  [  144/  696]
# loss: 0.117242  [  272/  696]
# loss: 0.158706  [  400/  696]
# loss: 0.075681  [  528/  696]
# loss: 0.184083  [  656/  696]
#
# Training Error:
#  Accuracy: 8.5%, Avg loss: 0.115011
#
# Validation Error:
#  Accuracy: 4.4%, Avg loss: 0.098638
#
#
# Epoch 44
# -------------------------------
# loss: 0.159594  [   16/  696]
# loss: 0.082197  [  144/  696]
# loss: 0.117566  [  272/  696]
# loss: 0.092808  [  400/  696]
# loss: 0.153862  [  528/  696]
# loss: 0.049029  [  656/  696]
#
# Training Error:
#  Accuracy: 6.6%, Avg loss: 0.114617
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.100715
#
#
# Epoch 45
# -------------------------------
# loss: 0.097780  [   16/  696]
# loss: 0.040443  [  144/  696]
# loss: 0.079509  [  272/  696]
# loss: 0.187710  [  400/  696]
# loss: 0.227477  [  528/  696]
# loss: 0.195762  [  656/  696]
#
# Training Error:
#  Accuracy: 12.4%, Avg loss: 0.114784
#
# Validation Error:
#  Accuracy: 9.8%, Avg loss: 0.100533
#
#
# Epoch 46
# -------------------------------
# loss: 0.158557  [   16/  696]
# loss: 0.042488  [  144/  696]
# loss: 0.084705  [  272/  696]
# loss: 0.153100  [  400/  696]
# loss: 0.122944  [  528/  696]
# loss: 0.194643  [  656/  696]
#
# Training Error:
#  Accuracy: 8.9%, Avg loss: 0.115904
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.096885
#
#
# Epoch 47
# -------------------------------
# loss: 0.080294  [   16/  696]
# loss: 0.119506  [  144/  696]
# loss: 0.049618  [  272/  696]
# loss: 0.039933  [  400/  696]
# loss: 0.125475  [  528/  696]
# loss: 0.194046  [  656/  696]
#
# Training Error:
#  Accuracy: 5.7%, Avg loss: 0.114791
#
# Validation Error:
#  Accuracy: 2.9%, Avg loss: 0.098042
#
#
# Epoch 48
# -------------------------------
# loss: 0.114393  [   16/  696]
# loss: 0.189604  [  144/  696]
# loss: 0.116836  [  272/  696]
# loss: 0.154430  [  400/  696]
# loss: 0.122473  [  528/  696]
# loss: 0.215570  [  656/  696]
#
# Training Error:
#  Accuracy: 12.5%, Avg loss: 0.114084
#
# Validation Error:
#  Accuracy: 2.9%, Avg loss: 0.106137
#
#
# Epoch 49
# -------------------------------
# loss: 0.041548  [   16/  696]
# loss: 0.071525  [  144/  696]
# loss: 0.115551  [  272/  696]
# loss: 0.082755  [  400/  696]
# loss: 0.081739  [  528/  696]
# loss: 0.041614  [  656/  696]
#
# Training Error:
#  Accuracy: 14.5%, Avg loss: 0.115197
#
# Validation Error:
#  Accuracy: 16.6%, Avg loss: 0.099034
#
#
# Epoch 50
# -------------------------------
# loss: 0.160365  [   16/  696]
# loss: 0.083558  [  144/  696]
# loss: 0.119835  [  272/  696]
# loss: 0.049703  [  400/  696]
# loss: 0.079648  [  528/  696]
# loss: 0.119849  [  656/  696]
#
# Training Error:
#  Accuracy: 13.9%, Avg loss: 0.113376
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.098578
#
#
# Epoch 51
# -------------------------------
# loss: 0.009422  [   16/  696]
# loss: 0.154734  [  144/  696]
# loss: 0.085318  [  272/  696]
# loss: 0.112527  [  400/  696]
# loss: 0.042265  [  528/  696]
# loss: 0.044687  [  656/  696]
#
# Training Error:
#  Accuracy: 7.2%, Avg loss: 0.113653
#
# Validation Error:
#  Accuracy: 15.6%, Avg loss: 0.097819
#
#
# Epoch 52
# -------------------------------
# loss: 0.153748  [   16/  696]
# loss: 0.118549  [  144/  696]
# loss: 0.234955  [  272/  696]
# loss: 0.122406  [  400/  696]
# loss: 0.160992  [  528/  696]
# loss: 0.120473  [  656/  696]
#
# Training Error:
#  Accuracy: 8.3%, Avg loss: 0.113930
#
# Validation Error:
#  Accuracy: 16.1%, Avg loss: 0.098136
#
#
# Epoch 53
# -------------------------------
# loss: 0.152852  [   16/  696]
# loss: 0.193582  [  144/  696]
# loss: 0.082575  [  272/  696]
# loss: 0.237633  [  400/  696]
# loss: 0.156443  [  528/  696]
# loss: 0.106596  [  656/  696]
#
# Training Error:
#  Accuracy: 14.8%, Avg loss: 0.116272
#
# Validation Error:
#  Accuracy: 9.3%, Avg loss: 0.102636
#
#
# Epoch 54
# -------------------------------
# loss: 0.178237  [   16/  696]
# loss: 0.007554  [  144/  696]
# loss: 0.079537  [  272/  696]
# loss: 0.155240  [  400/  696]
# loss: 0.041370  [  528/  696]
# loss: 0.080093  [  656/  696]
#
# Training Error:
#  Accuracy: 22.6%, Avg loss: 0.115690
#
# Validation Error:
#  Accuracy: 18.0%, Avg loss: 0.097845
#
#
# Epoch 55
# -------------------------------
# loss: 0.233252  [   16/  696]
# loss: 0.087327  [  144/  696]
# loss: 0.267480  [  272/  696]
# loss: 0.081292  [  400/  696]
# loss: 0.080019  [  528/  696]
# loss: 0.116987  [  656/  696]
#
# Training Error:
#  Accuracy: 15.4%, Avg loss: 0.115523
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.098649
#
#
# Epoch 56
# -------------------------------
# loss: 0.119978  [   16/  696]
# loss: 0.120998  [  144/  696]
# loss: 0.128733  [  272/  696]
# loss: 0.082160  [  400/  696]
# loss: 0.089178  [  528/  696]
# loss: 0.157254  [  656/  696]
#
# Training Error:
#  Accuracy: 8.2%, Avg loss: 0.115211
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.098140
#
#
# Epoch 57
# -------------------------------
# loss: 0.040554  [   16/  696]
# loss: 0.164791  [  144/  696]
# loss: 0.156131  [  272/  696]
# loss: 0.199138  [  400/  696]
# loss: 0.120861  [  528/  696]
# loss: 0.083472  [  656/  696]
#
# Training Error:
#  Accuracy: 9.2%, Avg loss: 0.113022
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.102454
#
#
# Epoch 58
# -------------------------------
# loss: 0.011269  [   16/  696]
# loss: 0.076710  [  144/  696]
# loss: 0.080694  [  272/  696]
# loss: 0.084563  [  400/  696]
# loss: 0.118431  [  528/  696]
# loss: 0.064616  [  656/  696]
#
# Training Error:
#  Accuracy: 14.7%, Avg loss: 0.113871
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.097537
#
#
# Epoch 59
# -------------------------------
# loss: 0.115271  [   16/  696]
# loss: 0.158624  [  144/  696]
# loss: 0.237596  [  272/  696]
# loss: 0.003400  [  400/  696]
# loss: 0.118906  [  528/  696]
# loss: 0.042288  [  656/  696]
#
# Training Error:
#  Accuracy: 11.1%, Avg loss: 0.113594
#
# Validation Error:
#  Accuracy: 8.8%, Avg loss: 0.104978
#
#
# Epoch 60
# -------------------------------
# loss: 0.111699  [   16/  696]
# loss: 0.188294  [  144/  696]
# loss: 0.116855  [  272/  696]
# loss: 0.083420  [  400/  696]
# loss: 0.163432  [  528/  696]
# loss: 0.121270  [  656/  696]
#
# Training Error:
#  Accuracy: 17.4%, Avg loss: 0.115949
#
# Validation Error:
#  Accuracy: 20.0%, Avg loss: 0.097308
#
#
# Epoch 61
# -------------------------------
# loss: 0.159912  [   16/  696]
# loss: 0.187060  [  144/  696]
# loss: 0.084903  [  272/  696]
# loss: 0.152043  [  400/  696]
# loss: 0.041305  [  528/  696]
# loss: 0.106710  [  656/  696]
#
# Training Error:
#  Accuracy: 12.4%, Avg loss: 0.113207
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.097516
#
#
# Epoch 62
# -------------------------------
# loss: 0.123428  [   16/  696]
# loss: 0.056676  [  144/  696]
# loss: 0.120291  [  272/  696]
# loss: 0.200495  [  400/  696]
# loss: 0.083009  [  528/  696]
# loss: 0.080699  [  656/  696]
#
# Training Error:
#  Accuracy: 4.5%, Avg loss: 0.116522
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.101405
#
#
# Epoch 63
# -------------------------------
# loss: 0.048622  [   16/  696]
# loss: 0.006175  [  144/  696]
# loss: 0.277383  [  272/  696]
# loss: 0.087090  [  400/  696]
# loss: 0.085155  [  528/  696]
# loss: 0.153780  [  656/  696]
#
# Training Error:
#  Accuracy: 3.9%, Avg loss: 0.112949
#
# Validation Error:
#  Accuracy: 2.9%, Avg loss: 0.097873
#
#
# Epoch 64
# -------------------------------
# loss: 0.121130  [   16/  696]
# loss: 0.079381  [  144/  696]
# loss: 0.080667  [  272/  696]
# loss: 0.002178  [  400/  696]
# loss: 0.124817  [  528/  696]
# loss: 0.120479  [  656/  696]
#
# Training Error:
#  Accuracy: 4.5%, Avg loss: 0.113673
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.099482
#
#
# Epoch 65
# -------------------------------
# loss: 0.003328  [   16/  696]
# loss: 0.044397  [  144/  696]
# loss: 0.086449  [  272/  696]
# loss: 0.160845  [  400/  696]
# loss: 0.116265  [  528/  696]
# loss: 0.046446  [  656/  696]
#
# Training Error:
#  Accuracy: 4.5%, Avg loss: 0.112646
#
# Validation Error:
#  Accuracy: 5.4%, Avg loss: 0.100101
#
#
# Epoch 66
# -------------------------------
# loss: 0.159884  [   16/  696]
# loss: 0.044334  [  144/  696]
# loss: 0.114836  [  272/  696]
# loss: 0.079394  [  400/  696]
# loss: 0.123187  [  528/  696]
# loss: 0.096645  [  656/  696]
#
# Training Error:
#  Accuracy: 6.0%, Avg loss: 0.115671
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.098800
#
#
# Epoch 67
# -------------------------------
# loss: 0.078248  [   16/  696]
# loss: 0.081958  [  144/  696]
# loss: 0.157244  [  272/  696]
# loss: 0.082534  [  400/  696]
# loss: 0.192836  [  528/  696]
# loss: 0.078376  [  656/  696]
#
# Training Error:
#  Accuracy: 4.9%, Avg loss: 0.116989
#
# Validation Error:
#  Accuracy: 3.4%, Avg loss: 0.100200
#
#
# Epoch 68
# -------------------------------
# loss: 0.235435  [   16/  696]
# loss: 0.157960  [  144/  696]
# loss: 0.004459  [  272/  696]
# loss: 0.101791  [  400/  696]
# loss: 0.158389  [  528/  696]
# loss: 0.153535  [  656/  696]
#
# Training Error:
#  Accuracy: 5.0%, Avg loss: 0.114106
#
# Validation Error:
#  Accuracy: 2.9%, Avg loss: 0.100429
#
#
# Epoch 69
# -------------------------------
# loss: 0.123174  [   16/  696]
# loss: 0.153189  [  144/  696]
# loss: 0.082184  [  272/  696]
# loss: 0.122498  [  400/  696]
# loss: 0.229941  [  528/  696]
# loss: 0.122269  [  656/  696]
#
# Training Error:
#  Accuracy: 5.9%, Avg loss: 0.115157
#
# Validation Error:
#  Accuracy: 4.9%, Avg loss: 0.099921
#
#
# Epoch 70
# -------------------------------
# loss: 0.120014  [   16/  696]
# loss: 0.069694  [  144/  696]
# loss: 0.126466  [  272/  696]
# loss: 0.175806  [  400/  696]
# loss: 0.187190  [  528/  696]
# loss: 0.080068  [  656/  696]
#
# Training Error:
#  Accuracy: 3.2%, Avg loss: 0.123412
#
# Validation Error:
#  Accuracy: 2.4%, Avg loss: 0.108819
#
#
# Epoch 71
# -------------------------------
# loss: 0.157402  [   16/  696]
# loss: 0.085181  [  144/  696]
# loss: 0.003520  [  272/  696]
# loss: 0.110082  [  400/  696]
# loss: 0.154451  [  528/  696]
# loss: 0.046188  [  656/  696]
#
# Training Error:
#  Accuracy: 7.5%, Avg loss: 0.123003
#
# Validation Error:
#  Accuracy: 3.4%, Avg loss: 0.105654
#
#
# Epoch 72
# -------------------------------
# loss: 0.118449  [   16/  696]
# loss: 0.106797  [  144/  696]
# loss: 0.149068  [  272/  696]
# loss: 0.108491  [  400/  696]
# loss: 0.232461  [  528/  696]
# loss: 0.118978  [  656/  696]
#
# Training Error:
#  Accuracy: 7.3%, Avg loss: 0.118229
#
# Validation Error:
#  Accuracy: 3.4%, Avg loss: 0.100092
#
#
# Epoch 73
# -------------------------------
# loss: 0.044483  [   16/  696]
# loss: 0.083012  [  144/  696]
# loss: 0.160098  [  272/  696]
# loss: 0.124736  [  400/  696]
# loss: 0.087256  [  528/  696]
# loss: 0.154012  [  656/  696]
#
# Training Error:
#  Accuracy: 4.7%, Avg loss: 0.114410
#
# Validation Error:
#  Accuracy: 5.4%, Avg loss: 0.103050
#
#
# Epoch 74
# -------------------------------
# loss: 0.084752  [   16/  696]
# loss: 0.043021  [  144/  696]
# loss: 0.079060  [  272/  696]
# loss: 0.081971  [  400/  696]
# loss: 0.123221  [  528/  696]
# loss: 0.140621  [  656/  696]
#
# Training Error:
#  Accuracy: 5.9%, Avg loss: 0.113863
#
# Validation Error:
#  Accuracy: 2.9%, Avg loss: 0.103771
#
#
# Epoch 75
# -------------------------------
# loss: 0.003010  [   16/  696]
# loss: 0.182373  [  144/  696]
# loss: 0.044929  [  272/  696]
# loss: 0.106916  [  400/  696]
# loss: 0.080402  [  528/  696]
# loss: 0.116737  [  656/  696]
#
# Training Error:
#  Accuracy: 5.2%, Avg loss: 0.125886
#
# Validation Error:
#  Accuracy: 3.4%, Avg loss: 0.111585
#
#
# Epoch 76
# -------------------------------
# loss: 0.071294  [   16/  696]
# loss: 0.163076  [  144/  696]
# loss: 0.118216  [  272/  696]
# loss: 0.099155  [  400/  696]
# loss: 0.108265  [  528/  696]
# loss: 0.110096  [  656/  696]
#
# Training Error:
#  Accuracy: 8.9%, Avg loss: 0.125578
#
# Validation Error:
#  Accuracy: 3.4%, Avg loss: 0.108271
#
#
# Epoch 77
# -------------------------------
# loss: 0.031417  [   16/  696]
# loss: 0.157677  [  144/  696]
# loss: 0.116744  [  272/  696]
# loss: 0.079628  [  400/  696]
# loss: 0.296203  [  528/  696]
# loss: 0.221903  [  656/  696]
#
# Training Error:
#  Accuracy: 8.6%, Avg loss: 0.123421
#
# Validation Error:
#  Accuracy: 6.3%, Avg loss: 0.105527
#
#
# Epoch 78
# -------------------------------
# loss: 0.117549  [   16/  696]
# loss: 0.108984  [  144/  696]
# loss: 0.081245  [  272/  696]
# loss: 0.142453  [  400/  696]
# loss: 0.083064  [  528/  696]
# loss: 0.167849  [  656/  696]
#
# Training Error:
#  Accuracy: 10.6%, Avg loss: 0.123207
#
# Validation Error:
#  Accuracy: 5.4%, Avg loss: 0.105386
#
#
# Epoch 79
# -------------------------------
# loss: 0.151457  [   16/  696]
# loss: 0.179252  [  144/  696]
# loss: 0.121460  [  272/  696]
# loss: 0.228318  [  400/  696]
# loss: 0.088648  [  528/  696]
# loss: 0.041056  [  656/  696]
#
# Training Error:
#  Accuracy: 10.2%, Avg loss: 0.122705
#
# Validation Error:
#  Accuracy: 8.3%, Avg loss: 0.106115
#
#
# Epoch 80
# -------------------------------
# loss: 0.069623  [   16/  696]
# loss: 0.154014  [  144/  696]
# loss: 0.104725  [  272/  696]
# loss: 0.156590  [  400/  696]
# loss: 0.107138  [  528/  696]
# loss: 0.179668  [  656/  696]
#
# Training Error:
#  Accuracy: 10.1%, Avg loss: 0.123508
#
# Validation Error:
#  Accuracy: 5.4%, Avg loss: 0.107502
#
#
# Epoch 81
# -------------------------------
# loss: 0.004872  [   16/  696]
# loss: 0.046681  [  144/  696]
# loss: 0.040664  [  272/  696]
# loss: 0.158769  [  400/  696]
# loss: 0.110463  [  528/  696]
# loss: 0.144481  [  656/  696]
#
# Training Error:
#  Accuracy: 9.9%, Avg loss: 0.118452
#
# Validation Error:
#  Accuracy: 5.4%, Avg loss: 0.105916
#
#
# Epoch 82
# -------------------------------
# loss: 0.119028  [   16/  696]
# loss: 0.005509  [  144/  696]
# loss: 0.083966  [  272/  696]
# loss: 0.164735  [  400/  696]
# loss: 0.115502  [  528/  696]
# loss: 0.108058  [  656/  696]
#
# Training Error:
#  Accuracy: 8.9%, Avg loss: 0.116398
#
# Validation Error:
#  Accuracy: 6.8%, Avg loss: 0.103403
#
#
# Epoch 83
# -------------------------------
# loss: 0.200665  [   16/  696]
# loss: 0.107207  [  144/  696]
# loss: 0.180511  [  272/  696]
# loss: 0.079352  [  400/  696]
# loss: 0.072277  [  528/  696]
# loss: 0.121328  [  656/  696]
#
# Training Error:
#  Accuracy: 10.1%, Avg loss: 0.114979
#
# Validation Error:
#  Accuracy: 9.3%, Avg loss: 0.099962
#
#
# Epoch 84
# -------------------------------
# loss: 0.015171  [   16/  696]
# loss: 0.123252  [  144/  696]
# loss: 0.082867  [  272/  696]
# loss: 0.115913  [  400/  696]
# loss: 0.227101  [  528/  696]
# loss: 0.225652  [  656/  696]
#
# Training Error:
#  Accuracy: 9.6%, Avg loss: 0.115195
#
# Validation Error:
#  Accuracy: 7.3%, Avg loss: 0.099995
#
#
# Epoch 85
# -------------------------------
# loss: 0.004322  [   16/  696]
# loss: 0.123581  [  144/  696]
# loss: 0.043102  [  272/  696]
# loss: 0.080029  [  400/  696]
# loss: 0.117759  [  528/  696]
# loss: 0.128091  [  656/  696]
#
# Training Error:
#  Accuracy: 8.2%, Avg loss: 0.113904
#
# Validation Error:
#  Accuracy: 6.3%, Avg loss: 0.099340
#
#
# Epoch 86
# -------------------------------
# loss: 0.081515  [   16/  696]
# loss: 0.156034  [  144/  696]
# loss: 0.044827  [  272/  696]
# loss: 0.118637  [  400/  696]
# loss: 0.077778  [  528/  696]
# loss: 0.043922  [  656/  696]
#
# Training Error:
#  Accuracy: 7.0%, Avg loss: 0.111367
#
# Validation Error:
#  Accuracy: 11.2%, Avg loss: 0.098563
#
#
# Epoch 87
# -------------------------------
# loss: 0.191599  [   16/  696]
# loss: 0.082849  [  144/  696]
# loss: 0.082302  [  272/  696]
# loss: 0.079983  [  400/  696]
# loss: 0.122826  [  528/  696]
# loss: 0.115526  [  656/  696]
#
# Training Error:
#  Accuracy: 4.2%, Avg loss: 0.112352
#
# Validation Error:
#  Accuracy: 4.9%, Avg loss: 0.100011
#
#
# Epoch 88
# -------------------------------
# loss: 0.117650  [   16/  696]
# loss: 0.117720  [  144/  696]
# loss: 0.156644  [  272/  696]
# loss: 0.080986  [  400/  696]
# loss: 0.082809  [  528/  696]
# loss: 0.081381  [  656/  696]
#
# Training Error:
#  Accuracy: 5.5%, Avg loss: 0.114048
#
# Validation Error:
#  Accuracy: 2.9%, Avg loss: 0.100033
#
#
# Epoch 89
# -------------------------------
# loss: 0.078775  [   16/  696]
# loss: 0.047452  [  144/  696]
# loss: 0.080688  [  272/  696]
# loss: 0.046218  [  400/  696]
# loss: 0.115514  [  528/  696]
# loss: 0.120358  [  656/  696]
#
# Training Error:
#  Accuracy: 7.9%, Avg loss: 0.112245
#
# Validation Error:
#  Accuracy: 9.3%, Avg loss: 0.096519
#
#
# Epoch 90
# -------------------------------
# loss: 0.197303  [   16/  696]
# loss: 0.192741  [  144/  696]
# loss: 0.195477  [  272/  696]
# loss: 0.117042  [  400/  696]
# loss: 0.081235  [  528/  696]
# loss: 0.080643  [  656/  696]
#
# Training Error:
#  Accuracy: 10.2%, Avg loss: 0.112145
#
# Validation Error:
#  Accuracy: 7.3%, Avg loss: 0.099973
#
#
# Epoch 91
# -------------------------------
# loss: 0.120300  [   16/  696]
# loss: 0.082618  [  144/  696]
# loss: 0.002001  [  272/  696]
# loss: 0.198147  [  400/  696]
# loss: 0.086285  [  528/  696]
# loss: 0.068154  [  656/  696]
#
# Training Error:
#  Accuracy: 12.4%, Avg loss: 0.127895
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.198751
#
#
# Epoch 92
# -------------------------------
# loss: 0.218018  [   16/  696]
# loss: 0.153456  [  144/  696]
# loss: 0.273662  [  272/  696]
# loss: 0.164960  [  400/  696]
# loss: 0.276520  [  528/  696]
# loss: 0.264211  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.228622
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.198724
#
#
# Epoch 93
# -------------------------------
# loss: 0.178012  [   16/  696]
# loss: 0.232648  [  144/  696]
# loss: 0.221545  [  272/  696]
# loss: 0.240194  [  400/  696]
# loss: 0.264437  [  528/  696]
# loss: 0.293931  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.228021
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.198298
#
#
# Epoch 94
# -------------------------------
# loss: 0.196619  [   16/  696]
# loss: 0.163874  [  144/  696]
# loss: 0.326066  [  272/  696]
# loss: 0.286807  [  400/  696]
# loss: 0.264492  [  528/  696]
# loss: 0.137537  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.229429
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.200399
#
#
# Epoch 95
# -------------------------------
# loss: 0.178491  [   16/  696]
# loss: 0.196120  [  144/  696]
# loss: 0.271419  [  272/  696]
# loss: 0.169182  [  400/  696]
# loss: 0.297610  [  528/  696]
# loss: 0.200244  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.229309
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.199475
#
#
# Epoch 96
# -------------------------------
# loss: 0.206035  [   16/  696]
# loss: 0.188225  [  144/  696]
# loss: 0.214289  [  272/  696]
# loss: 0.238155  [  400/  696]
# loss: 0.320900  [  528/  696]
# loss: 0.216889  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.228084
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.198235
#
#
# Epoch 97
# -------------------------------
# loss: 0.134459  [   16/  696]
# loss: 0.304974  [  144/  696]
# loss: 0.206341  [  272/  696]
# loss: 0.153893  [  400/  696]
# loss: 0.264371  [  528/  696]
# loss: 0.182969  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.227821
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.198205
#
#
# Epoch 98
# -------------------------------
# loss: 0.220970  [   16/  696]
# loss: 0.264235  [  144/  696]
# loss: 0.214741  [  272/  696]
# loss: 0.122589  [  400/  696]
# loss: 0.217503  [  528/  696]
# loss: 0.249327  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.229763
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.198758
#
#
# Epoch 99
# -------------------------------
# loss: 0.334103  [   16/  696]
# loss: 0.267712  [  144/  696]
# loss: 0.224977  [  272/  696]
# loss: 0.159836  [  400/  696]
# loss: 0.163983  [  528/  696]
# loss: 0.235478  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.228781
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.198522
#
#
# Epoch 100
# -------------------------------
# loss: 0.250791  [   16/  696]
# loss: 0.298842  [  144/  696]
# loss: 0.197679  [  272/  696]
# loss: 0.248126  [  400/  696]
# loss: 0.233280  [  528/  696]
# loss: 0.116680  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.229562
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.199873
#
#
# Epoch 101
# -------------------------------
# loss: 0.233242  [   16/  696]
# loss: 0.286890  [  144/  696]
# loss: 0.194904  [  272/  696]
# loss: 0.205034  [  400/  696]
# loss: 0.176173  [  528/  696]
# loss: 0.268921  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.227887
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.198694
#
#
# Epoch 102
# -------------------------------
# loss: 0.192981  [   16/  696]
# loss: 0.298048  [  144/  696]
# loss: 0.173083  [  272/  696]
# loss: 0.153202  [  400/  696]
# loss: 0.202266  [  528/  696]
# loss: 0.288376  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.228186
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.199705
#
#
# Epoch 103
# -------------------------------
# loss: 0.228374  [   16/  696]
# loss: 0.208344  [  144/  696]
# loss: 0.278156  [  272/  696]
# loss: 0.191507  [  400/  696]
# loss: 0.226311  [  528/  696]
# loss: 0.170489  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.228166
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.197039
#
#
# Epoch 104
# -------------------------------
# loss: 0.238950  [   16/  696]
# loss: 0.244719  [  144/  696]
# loss: 0.197090  [  272/  696]
# loss: 0.160809  [  400/  696]
# loss: 0.155273  [  528/  696]
# loss: 0.181972  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.228582
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.198039
#
#
# Epoch 105
# -------------------------------
# loss: 0.165598  [   16/  696]
# loss: 0.150180  [  144/  696]
# loss: 0.278954  [  272/  696]
# loss: 0.217785  [  400/  696]
# loss: 0.238230  [  528/  696]
# loss: 0.301682  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.227141
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.201049
#
#
# Epoch 106
# -------------------------------
# loss: 0.198353  [   16/  696]
# loss: 0.180408  [  144/  696]
# loss: 0.244365  [  272/  696]
# loss: 0.157052  [  400/  696]
# loss: 0.230680  [  528/  696]
# loss: 0.257753  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.229900
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.198128
#
#
# Epoch 107
# -------------------------------
# loss: 0.166791  [   16/  696]
# loss: 0.240002  [  144/  696]
# loss: 0.162446  [  272/  696]
# loss: 0.163884  [  400/  696]
# loss: 0.213058  [  528/  696]
# loss: 0.129196  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.230023
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.197317
#
#
# Epoch 108
# -------------------------------
# loss: 0.244692  [   16/  696]
# loss: 0.210860  [  144/  696]
# loss: 0.304472  [  272/  696]
# loss: 0.284412  [  400/  696]
# loss: 0.229663  [  528/  696]
# loss: 0.220047  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.226305
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.199855
#
#
# Epoch 109
# -------------------------------
# loss: 0.221872  [   16/  696]
# loss: 0.277256  [  144/  696]
# loss: 0.222155  [  272/  696]
# loss: 0.189023  [  400/  696]
# loss: 0.188077  [  528/  696]
# loss: 0.217349  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.228577
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.197294
#
#
# Epoch 110
# -------------------------------
# loss: 0.333236  [   16/  696]
# loss: 0.238575  [  144/  696]
# loss: 0.207170  [  272/  696]
# loss: 0.189330  [  400/  696]
# loss: 0.192044  [  528/  696]
# loss: 0.247962  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.229226
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.198432
#
#
# Epoch 111
# -------------------------------
# loss: 0.277673  [   16/  696]
# loss: 0.179359  [  144/  696]
# loss: 0.273019  [  272/  696]
# loss: 0.224671  [  400/  696]
# loss: 0.155886  [  528/  696]
# loss: 0.201003  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.230642
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.198529
#
#
# Epoch 112
# -------------------------------
# loss: 0.180078  [   16/  696]
# loss: 0.190835  [  144/  696]
# loss: 0.389780  [  272/  696]
# loss: 0.288443  [  400/  696]
# loss: 0.220229  [  528/  696]
# loss: 0.286294  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.229290
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.199040
#
#
# Epoch 113
# -------------------------------
# loss: 0.264349  [   16/  696]
# loss: 0.196431  [  144/  696]
# loss: 0.257597  [  272/  696]
# loss: 0.231654  [  400/  696]
# loss: 0.317406  [  528/  696]
# loss: 0.119670  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.228552
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.197910
#
#
# Epoch 114
# -------------------------------
# loss: 0.140763  [   16/  696]
# loss: 0.251363  [  144/  696]
# loss: 0.288332  [  272/  696]
# loss: 0.289553  [  400/  696]
# loss: 0.123776  [  528/  696]
# loss: 0.191451  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.227183
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.198381
#
#
# Epoch 115
# -------------------------------
# loss: 0.239178  [   16/  696]
# loss: 0.278671  [  144/  696]
# loss: 0.289231  [  272/  696]
# loss: 0.189998  [  400/  696]
# loss: 0.138696  [  528/  696]
# loss: 0.246939  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.228921
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.198915
#
#
# Epoch 116
# -------------------------------
# loss: 0.208178  [   16/  696]
# loss: 0.169231  [  144/  696]
# loss: 0.315357  [  272/  696]
# loss: 0.212103  [  400/  696]
# loss: 0.120798  [  528/  696]
# loss: 0.222331  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.228227
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.199702
#
#
# Epoch 117
# -------------------------------
# loss: 0.296599  [   16/  696]
# loss: 0.141235  [  144/  696]
# loss: 0.190998  [  272/  696]
# loss: 0.299283  [  400/  696]
# loss: 0.244236  [  528/  696]
# loss: 0.260995  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.228610
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.198904
#
#
# Epoch 118
# -------------------------------
# loss: 0.162786  [   16/  696]
# loss: 0.191669  [  144/  696]
# loss: 0.166116  [  272/  696]
# loss: 0.271129  [  400/  696]
# loss: 0.192111  [  528/  696]
# loss: 0.298261  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.227577
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.197964
#
#
# Epoch 119
# -------------------------------
# loss: 0.329000  [   16/  696]
# loss: 0.264365  [  144/  696]
# loss: 0.222025  [  272/  696]
# loss: 0.389583  [  400/  696]
# loss: 0.282726  [  528/  696]
# loss: 0.109504  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.228184
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.199424
#
#
# Epoch 120
# -------------------------------
# loss: 0.188808  [   16/  696]
# loss: 0.273480  [  144/  696]
# loss: 0.335428  [  272/  696]
# loss: 0.181849  [  400/  696]
# loss: 0.242651  [  528/  696]
# loss: 0.190372  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.228938
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.197730
#
#
# Epoch 121
# -------------------------------
# loss: 0.168935  [   16/  696]
# loss: 0.175505  [  144/  696]
# loss: 0.151423  [  272/  696]
# loss: 0.307954  [  400/  696]
# loss: 0.205045  [  528/  696]
# loss: 0.306892  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.229290
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.199465
#
#
# Epoch 122
# -------------------------------
# loss: 0.176130  [   16/  696]
# loss: 0.312223  [  144/  696]
# loss: 0.321102  [  272/  696]
# loss: 0.152869  [  400/  696]
# loss: 0.323356  [  528/  696]
# loss: 0.127983  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.226849
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.199097
#
#
# Epoch 123
# -------------------------------
# loss: 0.181941  [   16/  696]
# loss: 0.341122  [  144/  696]
# loss: 0.336214  [  272/  696]
# loss: 0.287950  [  400/  696]
# loss: 0.264414  [  528/  696]
# loss: 0.262726  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.228603
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.196904
#
#
# Epoch 124
# -------------------------------
# loss: 0.344522  [   16/  696]
# loss: 0.296378  [  144/  696]
# loss: 0.154506  [  272/  696]
# loss: 0.202130  [  400/  696]
# loss: 0.263284  [  528/  696]
# loss: 0.189279  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.229825
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.200368
#
#
# Epoch 125
# -------------------------------
# loss: 0.247731  [   16/  696]
# loss: 0.292181  [  144/  696]
# loss: 0.250107  [  272/  696]
# loss: 0.330763  [  400/  696]
# loss: 0.218831  [  528/  696]
# loss: 0.269346  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.228237
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.197339
#
#
# Epoch 126
# -------------------------------
# loss: 0.173746  [   16/  696]
# loss: 0.279139  [  144/  696]
# loss: 0.222681  [  272/  696]
# loss: 0.332875  [  400/  696]
# loss: 0.231602  [  528/  696]
# loss: 0.214061  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.227626
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.198844
#
#
# Epoch 127
# -------------------------------
# loss: 0.310486  [   16/  696]
# loss: 0.240908  [  144/  696]
# loss: 0.262698  [  272/  696]
# loss: 0.229029  [  400/  696]
# loss: 0.129963  [  528/  696]
# loss: 0.319383  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.230002
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.199399
#
#
# Epoch 128
# -------------------------------
# loss: 0.252510  [   16/  696]
# loss: 0.328881  [  144/  696]
# loss: 0.310270  [  272/  696]
# loss: 0.158449  [  400/  696]
# loss: 0.285280  [  528/  696]
# loss: 0.276669  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.227882
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.198630
#
#
# Epoch 129
# -------------------------------
# loss: 0.295209  [   16/  696]
# loss: 0.204713  [  144/  696]
# loss: 0.258108  [  272/  696]
# loss: 0.150862  [  400/  696]
# loss: 0.157946  [  528/  696]
# loss: 0.114128  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.228143
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.199677
#
#
# Epoch 130
# -------------------------------
# loss: 0.074659  [   16/  696]
# loss: 0.154546  [  144/  696]
# loss: 0.274492  [  272/  696]
# loss: 0.285452  [  400/  696]
# loss: 0.291750  [  528/  696]
# loss: 0.156807  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.229192
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.199527
#
#
# Epoch 131
# -------------------------------
# loss: 0.229992  [   16/  696]
# loss: 0.296297  [  144/  696]
# loss: 0.255146  [  272/  696]
# loss: 0.211462  [  400/  696]
# loss: 0.209693  [  528/  696]
# loss: 0.257129  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.229506
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.198642
#
#
# Epoch 132
# -------------------------------
# loss: 0.143984  [   16/  696]
# loss: 0.270233  [  144/  696]
# loss: 0.170169  [  272/  696]
# loss: 0.203210  [  400/  696]
# loss: 0.254405  [  528/  696]
# loss: 0.347387  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.230262
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.197966
#
#
# Epoch 133
# -------------------------------
# loss: 0.306080  [   16/  696]
# loss: 0.327717  [  144/  696]
# loss: 0.302930  [  272/  696]
# loss: 0.121558  [  400/  696]
# loss: 0.245645  [  528/  696]
# loss: 0.241005  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.228143
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.199784
#
#
# Epoch 134
# -------------------------------
# loss: 0.218907  [   16/  696]
# loss: 0.180508  [  144/  696]
# loss: 0.241977  [  272/  696]
# loss: 0.279521  [  400/  696]
# loss: 0.303624  [  528/  696]
# loss: 0.195864  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.228729
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.199678
#
#
# Epoch 135
# -------------------------------
# loss: 0.171539  [   16/  696]
# loss: 0.320119  [  144/  696]
# loss: 0.175960  [  272/  696]
# loss: 0.104773  [  400/  696]
# loss: 0.168851  [  528/  696]
# loss: 0.258076  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.229441
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.199400
#
#
# Epoch 136
# -------------------------------
# loss: 0.309371  [   16/  696]
# loss: 0.286529  [  144/  696]
# loss: 0.231185  [  272/  696]
# loss: 0.148702  [  400/  696]
# loss: 0.255300  [  528/  696]
# loss: 0.196337  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.227809
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.200202
#
#
# Epoch 137
# -------------------------------
# loss: 0.115032  [   16/  696]
# loss: 0.074509  [  144/  696]
# loss: 0.148980  [  272/  696]
# loss: 0.203920  [  400/  696]
# loss: 0.373513  [  528/  696]
# loss: 0.248952  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.228025
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.199540
#
#
# Epoch 138
# -------------------------------
# loss: 0.347991  [   16/  696]
# loss: 0.213317  [  144/  696]
# loss: 0.338995  [  272/  696]
# loss: 0.234189  [  400/  696]
# loss: 0.211889  [  528/  696]
# loss: 0.157072  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.228425
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.199323
#
#
# Epoch 139
# -------------------------------
# loss: 0.186816  [   16/  696]
# loss: 0.154816  [  144/  696]
# loss: 0.182515  [  272/  696]
# loss: 0.147647  [  400/  696]
# loss: 0.208205  [  528/  696]
# loss: 0.261316  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.228700
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.198535
#
#
# Epoch 140
# -------------------------------
# loss: 0.316049  [   16/  696]
# loss: 0.137864  [  144/  696]
# loss: 0.218022  [  272/  696]
# loss: 0.275783  [  400/  696]
# loss: 0.338517  [  528/  696]
# loss: 0.191954  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.229296
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.198852
#
#
# Epoch 141
# -------------------------------
# loss: 0.247325  [   16/  696]
# loss: 0.352803  [  144/  696]
# loss: 0.181312  [  272/  696]
# loss: 0.159822  [  400/  696]
# loss: 0.333472  [  528/  696]
# loss: 0.157217  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.228427
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.197603
#
#
# Epoch 142
# -------------------------------
# loss: 0.233528  [   16/  696]
# loss: 0.167481  [  144/  696]
# loss: 0.203957  [  272/  696]
# loss: 0.222563  [  400/  696]
# loss: 0.321371  [  528/  696]
# loss: 0.114767  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.228991
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.197875
#
#
# Epoch 143
# -------------------------------
# loss: 0.211936  [   16/  696]
# loss: 0.239913  [  144/  696]
# loss: 0.314449  [  272/  696]
# loss: 0.209764  [  400/  696]
# loss: 0.243993  [  528/  696]
# loss: 0.151514  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.227757
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.197861
#
# ...
# loss: 0.187872  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.227640
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.199557
#
#
# Epoch 1954
# -------------------------------
# loss: 0.260130  [   16/  696]
# loss: 0.171766  [  144/  696]
# loss: 0.315292  [  272/  696]
# loss: 0.317246  [  400/  696]
# loss: 0.282300  [  528/  696]
# loss: 0.240478  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.228923
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.199320
#
#
# Epoch 1955
# -------------------------------
# loss: 0.234754  [   16/  696]
# loss: 0.438570  [  144/  696]
# loss: 0.241841  [  272/  696]
# loss: 0.225617  [  400/  696]
# loss: 0.197422  [  528/  696]
# loss: 0.284207  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.226769
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.198123
#
#
# Epoch 1956
# -------------------------------
# loss: 0.193814  [   16/  696]
# loss: 0.262405  [  144/  696]
# loss: 0.230184  [  272/  696]
# loss: 0.139636  [  400/  696]
# loss: 0.147810  [  528/  696]
# loss: 0.301099  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.230067
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.197953
#
#
# Epoch 1957
# -------------------------------
# loss: 0.264486  [   16/  696]
# loss: 0.193821  [  144/  696]
# loss: 0.254917  [  272/  696]
# loss: 0.281937  [  400/  696]
# loss: 0.164712  [  528/  696]
# loss: 0.195468  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.230482
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.198770
#
#
# Epoch 1958
# -------------------------------
# loss: 0.185574  [   16/  696]
# loss: 0.211546  [  144/  696]
# loss: 0.258174  [  272/  696]
# loss: 0.157319  [  400/  696]
# loss: 0.196113  [  528/  696]
# loss: 0.261489  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.227565
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.200229
#
#
# Epoch 1959
# -------------------------------
# loss: 0.322628  [   16/  696]
# loss: 0.214630  [  144/  696]
# loss: 0.156295  [  272/  696]
# loss: 0.202345  [  400/  696]
# loss: 0.184061  [  528/  696]
# loss: 0.359456  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.228677
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.200404
#
#
# Epoch 1960
# -------------------------------
# loss: 0.132045  [   16/  696]
# loss: 0.230478  [  144/  696]
# loss: 0.118770  [  272/  696]
# loss: 0.285445  [  400/  696]
# loss: 0.298175  [  528/  696]
# loss: 0.284929  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.228236
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.198399
#
#
# Epoch 1961
# -------------------------------
# loss: 0.201615  [   16/  696]
# loss: 0.208608  [  144/  696]
# loss: 0.193434  [  272/  696]
# loss: 0.176302  [  400/  696]
# loss: 0.316624  [  528/  696]
# loss: 0.277580  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.228478
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.198926
#
#
# Epoch 1962
# -------------------------------
# loss: 0.183408  [   16/  696]
# loss: 0.126559  [  144/  696]
# loss: 0.129801  [  272/  696]
# loss: 0.259524  [  400/  696]
# loss: 0.258526  [  528/  696]
# loss: 0.257248  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.227308
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.200546
#
#
# Epoch 1963
# -------------------------------
# loss: 0.256668  [   16/  696]
# loss: 0.258962  [  144/  696]
# loss: 0.247415  [  272/  696]
# loss: 0.190703  [  400/  696]
# loss: 0.279390  [  528/  696]
# loss: 0.204053  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.227572
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.200404
#
#
# Epoch 1964
# -------------------------------
# loss: 0.112690  [   16/  696]
# loss: 0.320994  [  144/  696]
# loss: 0.175883  [  272/  696]
# loss: 0.250199  [  400/  696]
# loss: 0.250683  [  528/  696]
# loss: 0.310354  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.228539
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.198493
#
#
# Epoch 1965
# -------------------------------
# loss: 0.242059  [   16/  696]
# loss: 0.233827  [  144/  696]
# loss: 0.171012  [  272/  696]
# loss: 0.218529  [  400/  696]
# loss: 0.330082  [  528/  696]
# loss: 0.286065  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.229463
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.200085
#
#
# Epoch 1966
# -------------------------------
# loss: 0.188657  [   16/  696]
# loss: 0.171169  [  144/  696]
# loss: 0.237637  [  272/  696]
# loss: 0.264835  [  400/  696]
# loss: 0.251731  [  528/  696]
# loss: 0.141878  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.228433
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.198195
#
#
# Epoch 1967
# -------------------------------
# loss: 0.179323  [   16/  696]
# loss: 0.213204  [  144/  696]
# loss: 0.140003  [  272/  696]
# loss: 0.244515  [  400/  696]
# loss: 0.333315  [  528/  696]
# loss: 0.188761  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.227558
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.198859
#
#
# Epoch 1968
# -------------------------------
# loss: 0.125920  [   16/  696]
# loss: 0.153409  [  144/  696]
# loss: 0.257708  [  272/  696]
# loss: 0.250757  [  400/  696]
# loss: 0.259051  [  528/  696]
# loss: 0.236584  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.229206
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.199302
#
#
# Epoch 1969
# -------------------------------
# loss: 0.258083  [   16/  696]
# loss: 0.115184  [  144/  696]
# loss: 0.232399  [  272/  696]
# loss: 0.206744  [  400/  696]
# loss: 0.123164  [  528/  696]
# loss: 0.272705  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.228154
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.197631
#
#
# Epoch 1970
# -------------------------------
# loss: 0.176674  [   16/  696]
# loss: 0.147014  [  144/  696]
# loss: 0.260238  [  272/  696]
# loss: 0.272984  [  400/  696]
# loss: 0.198687  [  528/  696]
# loss: 0.328668  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.228368
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.200660
#
#
# Epoch 1971
# -------------------------------
# loss: 0.253825  [   16/  696]
# loss: 0.249536  [  144/  696]
# loss: 0.281769  [  272/  696]
# loss: 0.217777  [  400/  696]
# loss: 0.130044  [  528/  696]
# loss: 0.263079  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.230496
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.199727
#
#
# Epoch 1972
# -------------------------------
# loss: 0.224327  [   16/  696]
# loss: 0.312510  [  144/  696]
# loss: 0.251310  [  272/  696]
# loss: 0.245935  [  400/  696]
# loss: 0.216897  [  528/  696]
# loss: 0.236558  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.228663
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.198464
#
#
# Epoch 1973
# -------------------------------
# loss: 0.257267  [   16/  696]
# loss: 0.209638  [  144/  696]
# loss: 0.255414  [  272/  696]
# loss: 0.167030  [  400/  696]
# loss: 0.318702  [  528/  696]
# loss: 0.194282  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.228649
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.199195
#
#
# Epoch 1974
# -------------------------------
# loss: 0.271279  [   16/  696]
# loss: 0.270004  [  144/  696]
# loss: 0.237755  [  272/  696]
# loss: 0.280326  [  400/  696]
# loss: 0.285346  [  528/  696]
# loss: 0.241834  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.228518
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.198134
#
#
# Epoch 1975
# -------------------------------
# loss: 0.332806  [   16/  696]
# loss: 0.221284  [  144/  696]
# loss: 0.150785  [  272/  696]
# loss: 0.252548  [  400/  696]
# loss: 0.141736  [  528/  696]
# loss: 0.119239  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.231020
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.198289
#
#
# Epoch 1976
# -------------------------------
# loss: 0.306179  [   16/  696]
# loss: 0.305421  [  144/  696]
# loss: 0.235499  [  272/  696]
# loss: 0.310424  [  400/  696]
# loss: 0.268673  [  528/  696]
# loss: 0.225598  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.228139
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.198597
#
#
# Epoch 1977
# -------------------------------
# loss: 0.188753  [   16/  696]
# loss: 0.176259  [  144/  696]
# loss: 0.211973  [  272/  696]
# loss: 0.294953  [  400/  696]
# loss: 0.195341  [  528/  696]
# loss: 0.190443  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.230083
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.200017
#
#
# Epoch 1978
# -------------------------------
# loss: 0.225213  [   16/  696]
# loss: 0.269837  [  144/  696]
# loss: 0.337628  [  272/  696]
# loss: 0.147413  [  400/  696]
# loss: 0.226152  [  528/  696]
# loss: 0.248832  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.228034
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.197977
#
#
# Epoch 1979
# -------------------------------
# loss: 0.174396  [   16/  696]
# loss: 0.209932  [  144/  696]
# loss: 0.303610  [  272/  696]
# loss: 0.188962  [  400/  696]
# loss: 0.152006  [  528/  696]
# loss: 0.179099  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.228744
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.199257
#
#
# Epoch 1980
# -------------------------------
# loss: 0.190635  [   16/  696]
# loss: 0.115251  [  144/  696]
# loss: 0.176168  [  272/  696]
# loss: 0.261953  [  400/  696]
# loss: 0.170324  [  528/  696]
# loss: 0.273502  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.230353
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.201168
#
#
# Epoch 1981
# -------------------------------
# loss: 0.274180  [   16/  696]
# loss: 0.195060  [  144/  696]
# loss: 0.167226  [  272/  696]
# loss: 0.228186  [  400/  696]
# loss: 0.173104  [  528/  696]
# loss: 0.168789  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.229292
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.198932
#
#
# Epoch 1982
# -------------------------------
# loss: 0.194983  [   16/  696]
# loss: 0.243362  [  144/  696]
# loss: 0.234025  [  272/  696]
# loss: 0.239640  [  400/  696]
# loss: 0.205271  [  528/  696]
# loss: 0.216667  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.228497
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.198527
#
#
# Epoch 1983
# -------------------------------
# loss: 0.241739  [   16/  696]
# loss: 0.245914  [  144/  696]
# loss: 0.200196  [  272/  696]
# loss: 0.124626  [  400/  696]
# loss: 0.241814  [  528/  696]
# loss: 0.368575  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.228637
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.198741
#
#
# Epoch 1984
# -------------------------------
# loss: 0.265244  [   16/  696]
# loss: 0.293530  [  144/  696]
# loss: 0.157510  [  272/  696]
# loss: 0.096741  [  400/  696]
# loss: 0.199852  [  528/  696]
# loss: 0.304774  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.229726
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.197988
#
#
# Epoch 1985
# -------------------------------
# loss: 0.259994  [   16/  696]
# loss: 0.186894  [  144/  696]
# loss: 0.211389  [  272/  696]
# loss: 0.267121  [  400/  696]
# loss: 0.240539  [  528/  696]
# loss: 0.110770  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.227673
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.198692
#
#
# Epoch 1986
# -------------------------------
# loss: 0.263373  [   16/  696]
# loss: 0.157587  [  144/  696]
# loss: 0.195611  [  272/  696]
# loss: 0.239836  [  400/  696]
# loss: 0.250480  [  528/  696]
# loss: 0.254040  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.228911
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.198763
#
#
# Epoch 1987
# -------------------------------
# loss: 0.281131  [   16/  696]
# loss: 0.282462  [  144/  696]
# loss: 0.262974  [  272/  696]
# loss: 0.222097  [  400/  696]
# loss: 0.204143  [  528/  696]
# loss: 0.288382  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.228592
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.200821
#
#
# Epoch 1988
# -------------------------------
# loss: 0.160029  [   16/  696]
# loss: 0.135983  [  144/  696]
# loss: 0.237735  [  272/  696]
# loss: 0.259662  [  400/  696]
# loss: 0.260505  [  528/  696]
# loss: 0.381537  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.228468
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.197926
#
#
# Epoch 1989
# -------------------------------
# loss: 0.169913  [   16/  696]
# loss: 0.215166  [  144/  696]
# loss: 0.284202  [  272/  696]
# loss: 0.126878  [  400/  696]
# loss: 0.232701  [  528/  696]
# loss: 0.227071  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.228953
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.199318
#
#
# Epoch 1990
# -------------------------------
# loss: 0.222434  [   16/  696]
# loss: 0.274297  [  144/  696]
# loss: 0.135276  [  272/  696]
# loss: 0.255049  [  400/  696]
# loss: 0.287206  [  528/  696]
# loss: 0.215200  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.228014
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.198094
#
#
# Epoch 1991
# -------------------------------
# loss: 0.270002  [   16/  696]
# loss: 0.244178  [  144/  696]
# loss: 0.306910  [  272/  696]
# loss: 0.234877  [  400/  696]
# loss: 0.169751  [  528/  696]
# loss: 0.192315  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.229596
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.198760
#
#
# Epoch 1992
# -------------------------------
# loss: 0.362890  [   16/  696]
# loss: 0.195130  [  144/  696]
# loss: 0.144166  [  272/  696]
# loss: 0.230582  [  400/  696]
# loss: 0.206183  [  528/  696]
# loss: 0.194156  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.229130
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.198525
#
#
# Epoch 1993
# -------------------------------
# loss: 0.196005  [   16/  696]
# loss: 0.222987  [  144/  696]
# loss: 0.193840  [  272/  696]
# loss: 0.304471  [  400/  696]
# loss: 0.178494  [  528/  696]
# loss: 0.121441  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.227320
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.199684
#
#
# Epoch 1994
# -------------------------------
# loss: 0.178213  [   16/  696]
# loss: 0.118504  [  144/  696]
# loss: 0.182030  [  272/  696]
# loss: 0.196881  [  400/  696]
# loss: 0.266803  [  528/  696]
# loss: 0.174271  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.231761
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.199710
#
#
# Epoch 1995
# -------------------------------
# loss: 0.289381  [   16/  696]
# loss: 0.301444  [  144/  696]
# loss: 0.196078  [  272/  696]
# loss: 0.243643  [  400/  696]
# loss: 0.263401  [  528/  696]
# loss: 0.217367  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.229932
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.198698
#
#
# Epoch 1996
# -------------------------------
# loss: 0.276389  [   16/  696]
# loss: 0.210462  [  144/  696]
# loss: 0.091315  [  272/  696]
# loss: 0.219567  [  400/  696]
# loss: 0.257776  [  528/  696]
# loss: 0.290487  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.229403
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.198647
#
#
# Epoch 1997
# -------------------------------
# loss: 0.103022  [   16/  696]
# loss: 0.201300  [  144/  696]
# loss: 0.183766  [  272/  696]
# loss: 0.264798  [  400/  696]
# loss: 0.233553  [  528/  696]
# loss: 0.260908  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.229190
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.199623
#
#
# Epoch 1998
# -------------------------------
# loss: 0.205741  [   16/  696]
# loss: 0.173958  [  144/  696]
# loss: 0.221942  [  272/  696]
# loss: 0.360908  [  400/  696]
# loss: 0.171252  [  528/  696]
# loss: 0.246700  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.228673
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.198823
#
#
# Epoch 1999
# -------------------------------
# loss: 0.236425  [   16/  696]
# loss: 0.261032  [  144/  696]
# loss: 0.259414  [  272/  696]
# loss: 0.156622  [  400/  696]
# loss: 0.285920  [  528/  696]
# loss: 0.144990  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.228819
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.197950
#
#
# Epoch 2000
# -------------------------------
# loss: 0.129612  [   16/  696]
# loss: 0.163171  [  144/  696]
# loss: 0.279373  [  272/  696]
# loss: 0.305389  [  400/  696]
# loss: 0.256059  [  528/  696]
# loss: 0.286597  [  656/  696]
#
# Training Error:
#  Accuracy: 2.3%, Avg loss: 0.228756
#
# Validation Error:
#  Accuracy: 2.0%, Avg loss: 0.197300
#
#
# Done!

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# (Accuracy vs Epoch)
axes[0].plot(train_acc, label="train")
axes[0].plot(val_acc, label="val")
axes[0].legend()
axes[0].set_xlabel("Epoch")
axes[0].set_ylabel("Accuracy")
axes[0].set_title("Accuracy vs Epoch")
axes[0].grid()
axes[1].set_ylim(0, 1)

# (Loss vs Epoch)
axes[1].plot(train_loss, label="train")
axes[1].plot(val_loss, label="val")
axes[1].legend()
axes[1].set_xlabel("Epoch")
axes[1].set_ylabel("Loss")
axes[1].set_title("Loss vs Epoch")
axes[1].grid()
axes[1].set_ylim(0, 0.3)

plt.tight_layout()
plt.show()

# %%
torch.save(model.state_dict(), "model_weights.pth")

# %%
# save the accuracy 
torch.save(train_acc, "train_acc.pth")
torch.save(val_acc, "val_acc.pth")
torch.save(train_loss, "train_loss.pth")
torch.save(val_loss, "val_loss.pth")

# %%
max(val_acc), max(train_acc)
# Out:
# (0.6439024390243903, 0.3864942528735632)

# %% [markdown]
# ## Evaluation of the model on the test set

# %%
model.eval()
# Out:
# ParametricLPNet(
#   (fc): Sequential(
#     (0): Linear(in_features=1, out_features=8, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=8, out_features=16, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=16, out_features=8, bias=True)
#   )
# )

# %%
u = torch.tensor([[0.25]], dtype=torch.float64)
x = torch.cat([io.linprog(*plp_true(ui)).detach().t() for ui in u])
u,x
# Out:
# (tensor([[0.2500]], dtype=torch.float64),
#  tensor([[-0.0500,  0.0500]], dtype=torch.float64))

# %%
x_pred = model(torch.tensor([[0.25]]))
x_pred
# Out:
# tensor([[-0.0352,  0.0626]], grad_fn=<StackBackward0>)

# %%
x, x_pred, torch.norm(x - x_pred)
# Out:
# (tensor([[-0.0500,  0.0500]], dtype=torch.float64),
#  tensor([[-0.0352,  0.0626]], grad_fn=<StackBackward0>),
#  tensor(0.0194, dtype=torch.float64, grad_fn=<LinalgVectorNormBackward0>))

# %%
val_loop(test_dataloader, model, loss_fn)
# Out:
# Validation Error:
#  Accuracy: 70.7%, Avg loss: 0.013342
# (0.01334177836542949, 0.7073170731707317)

# %% [markdown]
# # Part 3: Deep IO model

# %%
plp_learn = ExamplePLP([1.5, 1.2])

# %%
u_show = io.tensor(np.linspace(-1.5, 1.5, 10).reshape((-1, 1)))
x_show = torch.cat([io.linprog(*plp_true(ui)).detach().t() for ui in u_show])

# Data set. Black points are the real solutions, blue points are the solutions of the plp_learn

iop.plot_targets(x_show, markersize=13)
iop.plot_parametric_linprog(plp_learn, u_show, color=[0, 0, 1], xylim=((-0.5,2.5),(-0.5,2.5)), cxy=(1.2,1.2), show_solutions=True)

# %%
u_show = io.tensor(np.linspace(1, 1.5, 10).reshape((-1, 1)))
x_show = torch.cat([io.linprog(*plp_true(ui)).detach().t() for ui in u_show])

# Data set. Black points are the real solutions, blue points are the solutions of the plp_learn

iop.plot_targets(x_show, markersize=13)
iop.plot_parametric_linprog(plp_learn, u_show, color=[0, 0, 1], xylim=((-0.5,2.5),(-0.5,2.5)), cxy=(1.2,1.2), show_solutions=True)

# %%
io.inverse_parametric_linprog(u_train, x_train, plp_learn, max_steps=10,
                              callback=io.inverse_parametric_linprog_step_printer())
# Out:
# inverse_parametric_linprog[0001]: loss=0.360737 weights=[1.5000 1.2000]
# inverse_parametric_linprog[0002]: loss=0.350147 weights=[1.3332 0.6538]
# inverse_parametric_linprog[0003]: loss=0.274222 weights=[1.2918 0.4963]
# inverse_parametric_linprog[0004]: loss=0.273151 weights=[1.2870 0.4853]
# inverse_parametric_linprog[0005]: loss=0.273150 weights=[1.2870 0.4852]
# inverse_parametric_linprog[0006]: loss=0.273149 weights=[1.2870 0.4853]
# inverse_parametric_linprog[0007]: loss=0.273147 weights=[1.2870 0.4852]
# inverse_parametric_linprog[0008]: loss=0.273144 weights=[1.2870 0.4852]
# inverse_parametric_linprog[0009]: loss=0.273143 weights=[1.2870 0.4851]
# inverse_parametric_linprog[0010]: loss=0.273142 weights=[1.2871 0.4851]
# inverse_parametric_linprog[done]: loss=0.273140 weights=[1.2871 0.4851]
# (<__main__.ExamplePLP at 0x7993613d66c0>,
#  tensor(0.2731, dtype=torch.float64, grad_fn=<MeanBackward0>),
#  tensor([[-0.0419,  0.0158],
#          [ 0.9922,  0.0869],
#          [ 0.9776,  0.1410],
#          ...,
#          [-0.1285,  0.0485],
#          [ 0.2570, -0.0969],
#          [-0.0698,  0.0263]], dtype=torch.float64, grad_fn=<CatBackward0>))

# %%
# Plot the new plp_learn, to show that the solutions (blue circles) now line up with the observed targets (black circles).
iop.plot_targets(x_show, markersize=13)
iop.plot_parametric_linprog(plp_learn, u_show, color=[0, 0, 1], xylim=((-0.5,2.5),(-0.5,2.5)), cxy=(1.2,1.2), show_solutions=True)

# %%
w = [1.2871, 0.4851]

estimated_plp = ExamplePLP(w)

res = [torch.norm(x - io.linprog(*estimated_plp(u)).t())<0.1 for u, x in zip(u_test, x_test)]
print(f"Train accuracy: {100*sum(res)/len(res):.2f}%")
# Out:
# Train accuracy: 55.28%
